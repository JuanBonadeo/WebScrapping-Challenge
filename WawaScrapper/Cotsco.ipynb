# %%
import requests
import pandas as pd
import time
import random
import concurrent.futures


def fetch_stores():
    print("Fetching stores.....")
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'en-us',
        'Connection': 'keep-alive',
        'DNT': '1',
        'Origin': 'https://www.costco.com',
        'Referer': 'https://www.costco.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'client_id': '45823696-9189-482d-89c3-0c067e477ea1',
        'latitude': '28.6305',
        'longitude': '-82.4497',
        'limit': '50',
        'openingDate': '2025-05-02',
    }

    response = requests.get('https://ecom-api.costco.com/warehouseLocatorMobile/v1/warehouses.json', params=params, headers=headers)

    response.raise_for_status()  # Raise an error for bad responses

    data = response.json()

    stores_data = data.get('warehouses', [])
    stores_dict_list = []
    
    for store in stores_data:
        store_dict = {
            'store_id': store.get('warehouseId'),
            'address': store.get('address', None).get('line1', None),
            'city': store.get('address', None).get('city', None),
            'state': store.get('address', None).get('territory', None),
            'zip_code': store.get('address', None).get('postalCode', None),
            'phone_number': store.get('phoneNumber'),
            'latitude': store.get('address', None).get('latitude', None),
            'longitude': store.get('address', None).get('longitude', None),
        }
        stores_dict_list.append(store_dict) 
    stores_df = pd.DataFrame(stores_dict_list)
    stores_df.drop_duplicates(subset='store_id', inplace=True)
    print("Finished fetching stores.")
    return stores_df

df_stores = fetch_stores()

if df_stores is not None:
    df_stores.to_csv('costco_stores.csv', index=False)
    print("Stores data saved to costco_stores.csv")
# Out:
# Fetching stores.....
# Finished fetching stores.
# Stores data saved to costco_stores.csv

# %%
#Fetch Categories

def fetch_categories():
    print("Fetching categories...")
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Connection': 'keep-alive',
        'DNT': '1',
        'Origin': 'https://www.costco.com',
        'Referer': 'https://www.costco.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'x-api-key': '273db6be-f015-4de7-b0d6-dd4746ccd5c3',
    }

    params = {
        'locale': 'en-US',
        'loc': '1250-3pl,1321-wm,1456-3pl,283-wm,561-wm,725-wm,731-wm,758-wm,759-wm,847_0-cor,847_0-cwt,847_0-edi,847_0-ehs,847_0-membership,847_0-mpt,847_0-spc,847_0-wm,847_1-cwt,847_1-edi,847_d-fis,847_lg_n1f-edi,847_NA-cor,847_NA-pharmacy,847_NA-wm,847_ss_u362-edi,847_wp_r458-edi,951-wm,952-wm,9847-wcs,115-bd,1249-wh',
        'chdmegamenu': 'true',
        'userLocation': 'WA',
        'userPostal': '98101',
    }

    response = requests.get(
        'https://search.costco.com/api/apps/www_costco_com/query/www_costco_com_megamenu',
        params=params,
        headers=headers,
    )

    response.raise_for_status()
    data = response.json()
    categories_data = data.get('megaMenu', {})
    categories_dict_list = []
    for category in categories_data:
        subcategories = category.get('children', [])
        if subcategories:
            for subcategory in subcategories:
                subcategory_dict = {
                    'category_id': subcategory.get('url').split('/')[-1],
                    'category_name': subcategory.get('name'),
                    'total_products': int(subcategory.get('count') or 0)
                }
                categories_dict_list.append(subcategory_dict)

    categories_df = pd.DataFrame(categories_dict_list)
    categories_df.drop_duplicates(subset='category_id', inplace=True)
    print("Finished fetching categories.")
    return categories_df

df_categories = fetch_categories()

if df_categories is not None:
    df_categories.to_csv('costco_categories.csv', index=False)
    print("Categories data saved to categories.csv")
# Out:
# Fetching categories...
# Finished fetching categories.
# Categories data saved to categories.csv

# %%
# Fetch Products
LIMIT = 100 

def fetch_products_in_category(row, store_id = '1262'):
    cat_id = row['category_id']
    total_products = row['total_products']
    cat_name = row['category_name']
    

    all_products = []
    skip = 0
    headers = {
    'Accept': 'application/json',
    'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    'DNT': '1',
    'Origin': 'https://www.costco.com',
    'Referer': 'https://www.costco.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'x-api-key': '273db6be-f015-4de7-b0d6-dd4746ccd5c3',
}


    while True:
        url = (
            'https://search.costco.com/api/apps/www_costco_com/query/www_costco_com_navigation'
            f'?expoption=def&q=*%3A*&locale=en-US&start={skip}&rows={LIMIT}&expand=false&userLocation=WA'
            f'&loc=115-bd%2C1-wh%2C1250-3pl%2C1321-wm%2C1456-3pl%2C283-wm%2C561-wm%2C725-wm%2C731-wm%2C758-wm%2C759-wm%2C847_0-cor'
            '%2C847_0-cwt%2C847_0-edi%2C847_0-ehs%2C847_0-membership%2C847_0-mpt%2C847_0-spc%2C847_0-wm%2C847_1-cwt%2C847_1-edi'
            '%2C847_d-fis%2C847_lg_n1f-edi%2C847_NA-cor%2C847_NA-pharmacy%2C847_NA-wm%2C847_ss_u362-edi%2C847_wp_r458-edi%2C951-wm'
            '%2C952-wm%2C9847-wcs&whloc=1-wh'
            f'&url=/{cat_id}'
            '&fq=%7B!tag%3Ditem_program_eligibility%7Ditem_program_eligibility%3A(%22ShipIt%22)'
            '&chdcategory=true&chdheader=true'
        )
        params = {
            'currenPage': skip // LIMIT, 
        }
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            data = response.json()
            products = data.get('response', {}).get('docs', [])
            all_products.extend(products)
            print(f'✅ Obtenidos {len(products)} productos de la categoría {cat_name} con skip {skip} en {store_id}')
        except Exception as e:
            print(f'❌ Error al obtener productos de la categoría {cat_name} con skip {skip} en {store_id}: {e}')
            break

        
        if len(products) < LIMIT:
            print(f'🛑 Ya no hay más productos para la categoría {cat_name} en {store_id}')
            sleep_time = random.randint(10, 30)
            print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
            time.sleep(sleep_time)
            break

        skip += LIMIT

        sleep_time = random.randint(10, 30)
        print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
        time.sleep(sleep_time)

    return all_products



def fetch_all_item_info(df_categories, max_workers=5):
    print('Fetching items info...')
    item_info_list = []
    # Crea el grupo de hilos
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        #Crea las tareas par cada categoria
        futures = [executor.submit(fetch_products_in_category, row, '1262') for _, row in df_categories.iterrows()]
        
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            try:
                result = future.result()
                item_info_list.extend(result)
                print(f'Completed {i+1}/{len(futures)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching item info.')
    return item_info_list



def parse_products_data(responses_list):
    print('Starting products-parsing...')
    item_dict_list = []
    for product in responses_list:
        name = product.get('name')
        id = product.get('id')
        upc_list = product.get('item_manufacturing_skus') or []
        category_path = product.get('categoryPath_ss') or []

        upc = upc_list[0] if upc_list else None
        category_id = category_path[0] if category_path else None
        brand = product.get('Brand_attr')
        weight = product.get('Weight_attr')
        height = product.get('Height_attr')
        width = product.get('Width_attr')
        length = product.get('Length_attr')
        color = product.get('Color_attr')

        item_dict = {
            'id': id,
            'name': name,
            'upc': upc,
            'category': category_id,
            'brand': brand,
            'weight': weight,
            'height': height,
            'width': width,
            'length': length,
            'color': color,
        }

        item_dict_list.append(item_dict)

    print(f'Parsed {len(item_dict_list)} items.')
    return item_dict_list



item_info_list = fetch_all_item_info( df_categories, 6)
item_dict_list = parse_products_data(item_info_list)
df_items = pd.DataFrame(item_dict_list)
df_items.to_csv('costco_productos.csv', index=False)
# Out:
# Fetching items info...
# ✅ Obtenidos 21 productos de la categoría Kitchen Appliance Packages con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Kitchen Appliance Packages en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 25 productos de la categoría Freezers & Ice Makers con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Freezers & Ice Makers en 1262
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Commercial & Restaurant Appliances con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Commercial & Restaurant Appliances en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 46 productos de la categoría Dishwashers con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dishwashers en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 57 productos de la categoría Heating, Cooling & Air Quality con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Heating, Cooling & Air Quality en 1262
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Cooking Appliances con skip 0 en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 1/246
# ✅ Obtenidos 23 productos de la categoría Microwaves con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Microwaves en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 2/246
# ✅ Obtenidos 100 productos de la categoría Refrigerators con skip 0 en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 3/246
# ✅ Obtenidos 93 productos de la categoría Small Kitchen Appliances con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Small Kitchen Appliances en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 4/246
# ✅ Obtenidos 16 productos de la categoría Small Space Appliances con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Small Space Appliances en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 5/246
# ✅ Obtenidos 49 productos de la categoría Vacuums & Floor Cleaning con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Vacuums & Floor Cleaning en 1262
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 19 productos de la categoría Cooking Appliances con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Cooking Appliances en 1262
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 46 productos de la categoría Refrigerators con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Refrigerators en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 6/246
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 0 en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 7/246
# ✅ Obtenidos 18 productos de la categoría Wine Coolers & Beverage Refrigerators con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wine Coolers & Beverage Refrigerators en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 8/246
# ✅ Obtenidos 6 productos de la categoría Baby Care & Safety con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Baby Care & Safety en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 9/246
# ✅ Obtenidos 12 productos de la categoría Baby Diapers, Wipes & Training Pants con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Baby Diapers, Wipes & Training Pants en 1262
# ⏳ Esperando 25s antes del próximo request...
# Completed 10/246
# ✅ Obtenidos 15 productos de la categoría Baby Formula & Feeding con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Baby Formula & Feeding en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 11/246
# ✅ Obtenidos 1 productos de la categoría Car & Booster Seats con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Car & Booster Seats en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 12/246
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 100 en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 15 productos de la categoría Nursery & Baby Furniture con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Nursery & Baby Furniture en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 13/246
# ✅ Obtenidos 15 productos de la categoría Bath & Body con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Bath & Body en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 14/246
# ✅ Obtenidos 11 productos de la categoría Beauty Gift Sets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Beauty Gift Sets en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 15/246
# Completed 16/246
# ✅ Obtenidos 3 productos de la categoría Beauty Supplements con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Beauty Supplements en 1262
# ⏳ Esperando 10s antes del próximo request...
# ✅ Obtenidos 29 productos de la categoría Beauty Tools & Accessories con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Beauty Tools & Accessories en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 17/246
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 200 en 1262
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 53 productos de la categoría Fragrances con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fragrances en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 18/246
# ✅ Obtenidos 50 productos de la categoría Hair Care con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Hair Care en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 19/246
# Completed 20/246
# ✅ Obtenidos 2 productos de la categoría Nail Care con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Nail Care en 1262
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 18 productos de la categoría Makeup con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Makeup en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 21/246
# ✅ Obtenidos 100 productos de la categoría Skin Care con skip 0 en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 22/246
# Completed 23/246
# Completed 24/246
# ✅ Obtenidos 15 productos de la categoría Sunscreen & Sun Care con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Sunscreen & Sun Care en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 29 productos de la categoría Clothing for Kids con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Clothing for Kids en 1262
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Clothing for Babies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Clothing for Babies en 1262
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 300 en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 25/246
# ✅ Obtenidos 100 productos de la categoría Clothing for Men con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Skin Care con skip 100 en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 26/246
# Completed 27/246
# ✅ Obtenidos 100 productos de la categoría Clothing for Women con skip 0 en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 41 productos de la categoría Clothing for Youth con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Clothing for Youth en 1262
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 77 productos de la categoría Clothing for Men con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Clothing for Men en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 28/246
# ✅ Obtenidos 30 productos de la categoría Dresswear con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dresswear en 1262
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 63 productos de la categoría Washers & Dryers con skip 400 en 1262
# 🛑 Ya no hay más productos para la categoría Washers & Dryers en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Skin Care con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Skin Care en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 29/246
# ✅ Obtenidos 10 productos de la categoría Fan Gear con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fan Gear en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 30/246
# ✅ Obtenidos 8 productos de la categoría Handbags & Wallets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Handbags & Wallets en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 31/246
# ✅ Obtenidos 7 productos de la categoría Holiday Clothing con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Holiday Clothing en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 32/246
# Completed 33/246
# ✅ Obtenidos 100 productos de la categoría Clothing for Women con skip 100 en 1262
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 43 productos de la categoría Luggage con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Luggage en 1262
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 64 productos de la categoría Shoes con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Shoes en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 34/246
# ✅ Obtenidos 75 productos de la categoría Sunglasses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Sunglasses en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 35/246
# ✅ Obtenidos 15 productos de la categoría Workwear con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Workwear en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 36/246
# ✅ Obtenidos 6 productos de la categoría Computer Accessories con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Computer Accessories en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 37/246
# ✅ Obtenidos 7 productos de la categoría Computer Software con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Computer Software en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 38/246
# ✅ Obtenidos 37 productos de la categoría Desktop Computers & PCs con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Desktop Computers & PCs en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 39/246
# ✅ Obtenidos 36 productos de la categoría Clothing for Women con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Clothing for Women en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 5 productos de la categoría Hard Drives, SSD & Storage con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Hard Drives, SSD & Storage en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 40/246
# ✅ Obtenidos 39 productos de la categoría iPad & Tablets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría iPad & Tablets en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 41/246
# Completed 42/246
# ✅ Obtenidos 100 productos de la categoría Laptops con skip 0 en 1262
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 32 productos de la categoría Monitors con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Monitors en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 43/246
# Completed 44/246
# ✅ Obtenidos 16 productos de la categoría PC Gaming con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría PC Gaming en 1262
# ⏳ Esperando 11s antes del próximo request...
# ✅ Obtenidos 20 productos de la categoría Printer Ink & Toner Cartridges con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Printer Ink & Toner Cartridges en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 45/246
# ✅ Obtenidos 14 productos de la categoría Printers con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Printers en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 46/246
# ✅ Obtenidos 8 productos de la categoría Routers, Wifi Extenders & Modems con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Routers, Wifi Extenders & Modems en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 47/246
# Completed 48/246
# ✅ Obtenidos 1 productos de la categoría Appliances con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Appliances en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 1 productos de la categoría Fitness con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fitness en 1262
# ⏳ Esperando 14s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Laptops con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Laptops en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 49/246
# ✅ Obtenidos 1 productos de la categoría Furniture con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Furniture en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 50/246
# ✅ Obtenidos 1 productos de la categoría Home Upgrades con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Home Upgrades en 1262
# ⏳ Esperando 15s antes del próximo request...
# Completed 51/246
# ✅ Obtenidos 1 productos de la categoría Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Mattresses en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 52/246
# ✅ Obtenidos 1 productos de la categoría Patio & Garden con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Patio & Garden en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 53/246
# ✅ Obtenidos 1 productos de la categoría Toys con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Toys en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 54/246
# ✅ Obtenidos 1 productos de la categoría TVs con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría TVs en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 55/246
# Completed 56/246
# ✅ Obtenidos 91 productos de la categoría Costco NEXT™ con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Costco NEXT™ en 1262
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 17 productos de la categoría Allstate Protection Plans con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Allstate Protection Plans en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 57/246
# Completed 58/246
# ✅ Obtenidos 78 productos de la categoría Apple Products con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Apple Products en 1262
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 49 productos de la categoría Audio/Video con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Audio/Video en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 59/246
# ✅ Obtenidos 8 productos de la categoría Batteries con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Batteries en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 60/246
# ✅ Obtenidos 4 productos de la categoría Cameras & Drones con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cameras & Drones en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 61/246
# ✅ Obtenidos 14 productos de la categoría Cell Phones & Accessories con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cell Phones & Accessories en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 62/246
# ✅ Obtenidos 10 productos de la categoría Gaming Gift Cards con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Gaming Gift Cards en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 63/246
# ✅ Obtenidos 17 productos de la categoría Musical Instruments con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Musical Instruments en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 64/246
# Completed 65/246
# ✅ Obtenidos 3 productos de la categoría Phones & Two-way Radios con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Phones & Two-way Radios en 1262
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 41 productos de la categoría Security Cameras & Home Security Systems con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Security Cameras & Home Security Systems en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 66/246
# ✅ Obtenidos 76 productos de la categoría Smart Home & Home Automation con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Smart Home & Home Automation en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 67/246
# Completed 68/246
# ✅ Obtenidos 43 productos de la categoría Video Games & Consoles con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Video Games & Consoles en 1262
# ⏳ Esperando 12s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría TVs con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 69/246
# Completed 70/246
# ✅ Obtenidos 52 productos de la categoría Flowers con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Flowers en 1262
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 30 productos de la categoría Wearable Technology con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wearable Technology en 1262
# ⏳ Esperando 22s antes del próximo request...
# Completed 71/246
# Completed 72/246
# ✅ Obtenidos 100 productos de la categoría Gift Baskets con skip 0 en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bedroom Furniture con skip 0 en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 73/246
# ✅ Obtenidos 42 productos de la categoría Entryway Furniture con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Entryway Furniture en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 44 productos de la categoría TVs con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría TVs en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 74/246
# ✅ Obtenidos 17 productos de la categoría Fireplaces and Stoves con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fireplaces and Stoves en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 75/246
# ✅ Obtenidos 38 productos de la categoría Kids' & Baby Furniture con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Kids' & Baby Furniture en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 76/246
# Completed 77/246
# ✅ Obtenidos 32 productos de la categoría Gift Baskets con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Gift Baskets en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Kitchen & Dining Room Furniture con skip 0 en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Living Room Furniture con skip 0 en 1262
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 81 productos de la categoría Bedroom Furniture con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Bedroom Furniture en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 78/246
# ✅ Obtenidos 100 productos de la categoría Office & Home Office Furniture con skip 0 en 1262
# ⏳ Esperando 11s antes del próximo request...
# ✅ Obtenidos 0 productos de la categoría Kitchen & Dining Room Furniture con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Kitchen & Dining Room Furniture en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 79/246
# Completed 80/246
# ✅ Obtenidos 2 productos de la categoría Costco Shop Cards con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Costco Shop Cards en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Entertainment & Lifestyle Gift Cards con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Entertainment & Lifestyle Gift Cards en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Living Room Furniture con skip 100 en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 81/246
# ✅ Obtenidos 3 productos de la categoría Office & Home Office Furniture con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Office & Home Office Furniture en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 3 productos de la categoría Health & Wellness Gift Cards con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Health & Wellness Gift Cards en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 82/246
# Completed 83/246
# ✅ Obtenidos 5 productos de la categoría Movie Tickets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Movie Tickets en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 42 productos de la categoría Restaurant Gift Cards con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Restaurant Gift Cards en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 84/246
# ✅ Obtenidos 23 productos de la categoría Sports Tickets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Sports Tickets en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 85/246
# Completed 86/246
# ✅ Obtenidos 3 productos de la categoría Theater & Live Events con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Theater & Live Events en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 9 productos de la categoría Living Room Furniture con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Living Room Furniture en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 12 productos de la categoría Theme Parks & Attractions con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Theme Parks & Attractions en 1262
# ⏳ Esperando 15s antes del próximo request...
# Completed 87/246
# ✅ Obtenidos 7 productos de la categoría Travel Gift Cards & Passes con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Travel Gift Cards & Passes en 1262
# ⏳ Esperando 25s antes del próximo request...
# Completed 88/246
# ✅ Obtenidos 100 productos de la categoría 2-Day Delivery con skip 0 en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 89/246
# ✅ Obtenidos 31 productos de la categoría Bakery & Desserts con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Bakery & Desserts en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 90/246
# ✅ Obtenidos 100 productos de la categoría Beverages & Water con skip 0 en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 91/246
# ✅ Obtenidos 21 productos de la categoría Breakfast con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Breakfast en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 92/246
# Completed 93/246
# ✅ Obtenidos 4 productos de la categoría Cheese & Dairy con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cheese & Dairy en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Candy con skip 0 en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 94/246
# ✅ Obtenidos 100 productos de la categoría Cleaning Supplies con skip 0 en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 95/246
# ✅ Obtenidos 49 productos de la categoría Beverages & Water con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Beverages & Water en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 99 productos de la categoría Coffee con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Coffee en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 21 productos de la categoría 2-Day Delivery con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría 2-Day Delivery en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 96/246
# ✅ Obtenidos 35 productos de la categoría Deli con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Deli en 1262
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 61 productos de la categoría Candy con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Candy en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 97/246
# Completed 98/246
# ✅ Obtenidos 32 productos de la categoría Emergency Food Supplies & Kits con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Emergency Food Supplies & Kits en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 99/246
# ✅ Obtenidos 100 productos de la categoría Kirkland Signature Grocery con skip 0 en 1262
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat & Seafood con skip 0 en 1262
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Cleaning Supplies con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Cleaning Supplies en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 100/246
# ✅ Obtenidos 36 productos de la categoría Organic Groceries con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Organic Groceries en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 101/246
# ✅ Obtenidos 100 productos de la categoría Pantry & Dry Goods con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 102/246
# ✅ Obtenidos 18 productos de la categoría Kirkland Signature Grocery con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Kirkland Signature Grocery en 1262
# ⏳ Esperando 10s antes del próximo request...
# ✅ Obtenidos 98 productos de la categoría Paper & Plastic Products con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Paper & Plastic Products en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 103/246
# ✅ Obtenidos 1 productos de la categoría Same-Day Delivery con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Same-Day Delivery en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 104/246
# ✅ Obtenidos 100 productos de la categoría Snacks con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 51 productos de la categoría Meat & Seafood con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Meat & Seafood en 1262
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 86 productos de la categoría Pantry & Dry Goods con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Pantry & Dry Goods en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 105/246
# ✅ Obtenidos 11 productos de la categoría Wine, Champagne & Sparkling con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wine, Champagne & Sparkling en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 106/246
# ✅ Obtenidos 2 productos de la categoría Costco Optical con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Costco Optical en 1262
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Snacks con skip 100 en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 107/246
# ✅ Obtenidos 100 productos de la categoría Health & Medicines con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 108/246
# ✅ Obtenidos 19 productos de la categoría Hearing Care Products con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Hearing Care Products en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 109/246
# ✅ Obtenidos 42 productos de la categoría Home Health Care con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Home Health Care en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 110/246
# Completed 111/246
# ✅ Obtenidos 40 productos de la categoría Massage Equipment con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Massage Equipment en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 84 productos de la categoría Nutrition con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Nutrition en 1262
# ⏳ Esperando 10s antes del próximo request...
# ✅ Obtenidos 70 productos de la categoría Health & Medicines con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Health & Medicines en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 112/246
# ✅ Obtenidos 100 productos de la categoría Personal Care con skip 0 en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 113/246
# Completed 114/246
# ✅ Obtenidos 89 productos de la categoría Snacks con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Snacks en 1262
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 7 productos de la categoría Spa Gifts & Aromatherapy con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Spa Gifts & Aromatherapy en 1262
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 12 productos de la categoría Reading Glasses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Reading Glasses en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 115/246
# ✅ Obtenidos 2 productos de la categoría Travel Immunizations con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Travel Immunizations en 1262
# ⏳ Esperando 25s antes del próximo request...
# Completed 116/246
# Completed 117/246
# ✅ Obtenidos 10 productos de la categoría Wheelchairs, Walkers & Medical Alert Devices con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wheelchairs, Walkers & Medical Alert Devices en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Vitamins, Herbals & Dietary Supplements con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 118/246
# ✅ Obtenidos 14 productos de la categoría Easter con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Easter en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 119/246
# ✅ Obtenidos 4 productos de la categoría Holiday Cards,Wrapping Paper & Ribbons con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Holiday Cards,Wrapping Paper & Ribbons en 1262
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 94 productos de la categoría Personal Care con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Personal Care en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 120/246
# ✅ Obtenidos 22 productos de la categoría Holiday Gift Baskets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Holiday Gift Baskets en 1262
# ⏳ Esperando 12s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Vitamins, Herbals & Dietary Supplements con skip 100 en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 121/246
# ✅ Obtenidos 2 productos de la categoría Mother's Day con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Mother's Day en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 122/246
# ✅ Obtenidos 1 productos de la categoría Bath Remodeling con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Bath Remodeling en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 123/246
# ✅ Obtenidos 1 productos de la categoría Cabinet Refacing con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cabinet Refacing en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 124/246
# ✅ Obtenidos 1 productos de la categoría Carpet & Flooring Installation con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Carpet & Flooring Installation en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 125/246
# ✅ Obtenidos 1 productos de la categoría Countertop Installation con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Countertop Installation en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 126/246
# ✅ Obtenidos 1 productos de la categoría Custom Blinds, Shades & Shutters con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Custom Blinds, Shades & Shutters en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 127/246
# ✅ Obtenidos 1 productos de la categoría Garage Door & Opener Installation con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Garage Door & Opener Installation en 1262
# ⏳ Esperando 25s antes del próximo request...
# Completed 128/246
# ✅ Obtenidos 1 productos de la categoría Generator Installation con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Generator Installation en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 30 productos de la categoría Vitamins, Herbals & Dietary Supplements con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Vitamins, Herbals & Dietary Supplements en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 129/246
# ✅ Obtenidos 1 productos de la categoría Home Organization Services con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Home Organization Services en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 130/246
# ✅ Obtenidos 1 productos de la categoría HVAC Installation con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría HVAC Installation en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 131/246
# ✅ Obtenidos 1 productos de la categoría Water Treatment Services con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Water Treatment Services en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 132/246
# Completed 133/246
# ✅ Obtenidos 1 productos de la categoría Windows & Doors con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Windows & Doors en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 134/246
# ✅ Obtenidos 100 productos de la categoría Bath con skip 0 en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 135/246
# ✅ Obtenidos 100 productos de la categoría Bedding con skip 0 en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 136/246
# ✅ Obtenidos 87 productos de la categoría Cookware & Bakeware con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cookware & Bakeware en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 31 productos de la categoría Cutlery & Kitchen Knives con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cutlery & Kitchen Knives en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 137/246
# ✅ Obtenidos 38 productos de la categoría Glassware & Drinkware con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Glassware & Drinkware en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 138/246
# ✅ Obtenidos 100 productos de la categoría Home Decor con skip 0 en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 139/246
# Completed 140/246
# ✅ Obtenidos 14 productos de la categoría Kitchen Linens & Towels con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Kitchen Linens & Towels en 1262
# ⏳ Esperando 11s antes del próximo request...
# ✅ Obtenidos 71 productos de la categoría Kitchen Storage & Organization con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Kitchen Storage & Organization en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 84 productos de la categoría Bath con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Bath en 1262
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 92 productos de la categoría Bedding con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Bedding en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 141/246
# Completed 142/246
# ✅ Obtenidos 27 productos de la categoría Kitchen Utensils & Gadgets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Kitchen Utensils & Gadgets en 1262
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Rugs con skip 0 en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 143/246
# ✅ Obtenidos 5 productos de la categoría Sewing & Garment Care con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Sewing & Garment Care en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Home Decor con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Home Decor en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 144/246
# ✅ Obtenidos 92 productos de la categoría Tableware con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Tableware en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 145/246
# Completed 146/246
# ✅ Obtenidos 100 productos de la categoría Rugs con skip 100 en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bathroom Remodel & Renovations con skip 0 en 1262
# ⏳ Esperando 11s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Building Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Building Supplies en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 147/246
# ✅ Obtenidos 7 productos de la categoría Fire Safety con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fire Safety en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 148/246
# ✅ Obtenidos 21 productos de la categoría Flooring con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Flooring en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 149/246
# ✅ Obtenidos 26 productos de la categoría Bathroom Remodel & Renovations con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Bathroom Remodel & Renovations en 1262
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 48 productos de la categoría Garage con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Garage en 1262
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Rugs con skip 200 en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 150/246
# ✅ Obtenidos 29 productos de la categoría Generators con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Generators en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 151/246
# ✅ Obtenidos 77 productos de la categoría Kitchen Remodel & Renovations con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Kitchen Remodel & Renovations en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 152/246
# ✅ Obtenidos 100 productos de la categoría Lighting & Ceiling Light Fixtures con skip 0 en 1262
# ⏳ Esperando 25s antes del próximo request...
# Completed 153/246
# Completed 154/246
# ✅ Obtenidos 16 productos de la categoría Safes con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Safes en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 155/246
# ✅ Obtenidos 38 productos de la categoría Storage & Organization con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Storage & Organization en 1262
# ⏳ Esperando 10s antes del próximo request...
# ✅ Obtenidos 23 productos de la categoría Tools & Hardware con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Tools & Hardware en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 156/246
# ✅ Obtenidos 69 productos de la categoría Bracelets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Bracelets en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 157/246
# Completed 158/246
# ✅ Obtenidos 36 productos de la categoría Rugs con skip 300 en 1262
# 🛑 Ya no hay más productos para la categoría Rugs en 1262
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Necklaces con skip 0 en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Earrings con skip 0 en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 0 productos de la categoría Lighting & Ceiling Light Fixtures con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Lighting & Ceiling Light Fixtures en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 159/246
# ✅ Obtenidos 5 productos de la categoría Precious Metals con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Precious Metals en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 160/246
# ✅ Obtenidos 100 productos de la categoría Rings con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Necklaces con skip 100 en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 161/246
# Completed 162/246
# ✅ Obtenidos 11 productos de la categoría Adjustable Beds con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Adjustable Beds en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Watches con skip 0 en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Earrings con skip 100 en 1262
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Rings con skip 100 en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 163/246
# ✅ Obtenidos 13 productos de la categoría California King Size Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría California King Size Mattresses en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 164/246
# ✅ Obtenidos 19 productos de la categoría Full Size Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Full Size Mattresses en 1262
# ⏳ Esperando 22s antes del próximo request...
# Completed 165/246
# ✅ Obtenidos 50 productos de la categoría Necklaces con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Necklaces en 1262
# ⏳ Esperando 10s antes del próximo request...
# ✅ Obtenidos 40 productos de la categoría King Size Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría King Size Mattresses en 1262
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 5 productos de la categoría Watches con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Watches en 1262
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 18 productos de la categoría Earrings con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Earrings en 1262
# ⏳ Esperando 25s antes del próximo request...
# Completed 166/246
# ✅ Obtenidos 44 productos de la categoría Queen Size Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Queen Size Mattresses en 1262
# ⏳ Esperando 10s antes del próximo request...
# ✅ Obtenidos 75 productos de la categoría Rings con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Rings en 1262
# ⏳ Esperando 15s antes del próximo request...
# Completed 167/246
# ✅ Obtenidos 13 productos de la categoría Twin Size Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Twin Size Mattresses en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 168/246
# ✅ Obtenidos 3 productos de la categoría Twin XL Size Mattresses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Twin XL Size Mattresses en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 169/246
# ✅ Obtenidos 11 productos de la categoría Basic Office Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Basic Office Supplies en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 170/246
# ✅ Obtenidos 9 productos de la categoría Filing, Binders & Storage con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Filing, Binders & Storage en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 171/246
# Completed 172/246
# ✅ Obtenidos 24 productos de la categoría Janitorial & Breakroom Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Janitorial & Breakroom Supplies en 1262
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Mailing, Packing & Shipping Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Mailing, Packing & Shipping Supplies en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 173/246
# ✅ Obtenidos 24 productos de la categoría Office Electronics con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Office Electronics en 1262
# ⏳ Esperando 18s antes del próximo request...
# Completed 174/246
# Completed 175/246
# ✅ Obtenidos 8 productos de la categoría Paper con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Paper en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Writing Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Writing Supplies en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 176/246
# ✅ Obtenidos 15 productos de la categoría Backyard Playground Sets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Backyard Playground Sets en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 177/246
# ✅ Obtenidos 12 productos de la categoría Greenhouses con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Greenhouses en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 178/246
# Completed 179/246
# ✅ Obtenidos 58 productos de la categoría Grills & Outdoor Cooking con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Grills & Outdoor Cooking en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Hot Tubs, Spas & Pools con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Hot Tubs, Spas & Pools en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 180/246
# ✅ Obtenidos 33 productos de la categoría Landscaping con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Landscaping en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 181/246
# Completed 182/246
# ✅ Obtenidos 92 productos de la categoría Lawn Care & Gardening Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Lawn Care & Gardening Supplies en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 31 productos de la categoría Outdoor Heating & Cooling con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Outdoor Heating & Cooling en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 183/246
# ✅ Obtenidos 37 productos de la categoría Outdoor Power Equipment con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Outdoor Power Equipment en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 184/246
# Completed 185/246
# ✅ Obtenidos 33 productos de la categoría Outdoor Storage Sheds con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Outdoor Storage Sheds en 1262
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Patio & Outdoor Furniture con skip 0 en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 186/246
# ✅ Obtenidos 61 productos de la categoría Patio Covers & Shade Structures con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Patio Covers & Shade Structures en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 187/246
# ✅ Obtenidos 100 productos de la categoría Plants, Bulbs & Seeds con skip 0 en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 188/246
# ✅ Obtenidos 4 productos de la categoría Window Treatments, Awnings & Sun Shades con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Window Treatments, Awnings & Sun Shades en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 189/246
# ✅ Obtenidos 6 productos de la categoría Cat Food con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cat Food en 1262
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Patio & Outdoor Furniture con skip 100 en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 190/246
# ✅ Obtenidos 5 productos de la categoría Cat Trees con skip 0 en 1262✅ Obtenidos 4 productos de la categoría Plants, Bulbs & Seeds con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Plants, Bulbs & Seeds en 1262
# ⏳ Esperando 18s antes del próximo request...
#
# 🛑 Ya no hay más productos para la categoría Cat Trees en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 191/246
# ✅ Obtenidos 17 productos de la categoría Dewormer, Flea & Tick Treatment con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dewormer, Flea & Tick Treatment en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 192/246
# ✅ Obtenidos 10 productos de la categoría Dog Beds con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dog Beds en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 193/246
# ✅ Obtenidos 16 productos de la categoría Dog Food con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dog Food en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 194/246
# ✅ Obtenidos 91 productos de la categoría Patio & Outdoor Furniture con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría Patio & Outdoor Furniture en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 195/246
# ✅ Obtenidos 7 productos de la categoría Pet Clothing & Accessories con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pet Clothing & Accessories en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Pet Enclosures con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pet Enclosures en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 196/246
# ✅ Obtenidos 7 productos de la categoría Pet Grooming & Waste Management con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pet Grooming & Waste Management en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 197/246
# ✅ Obtenidos 21 productos de la categoría Pet Supplements con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pet Supplements en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 198/246
# ✅ Obtenidos 8 productos de la categoría Pet Technology con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pet Technology en 1262
# ⏳ Esperando 22s antes del próximo request...
# Completed 199/246
# ✅ Obtenidos 34 productos de la categoría Pet Toys & Treats con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pet Toys & Treats en 1262
# ⏳ Esperando 15s antes del próximo request...
# Completed 200/246
# ✅ Obtenidos 100 productos de la categoría Special Events con skip 0 en 1262
# ⏳ Esperando 21s antes del próximo request...
# Completed 201/246
# Completed 202/246
# ✅ Obtenidos 100 productos de la categoría Beach con skip 0 en 1262
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 19 productos de la categoría Bikes, Scooters & Boards con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Bikes, Scooters & Boards en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 203/246
# ✅ Obtenidos 95 productos de la categoría Camping Gear con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Camping Gear en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 204/246
# ✅ Obtenidos 26 productos de la categoría Fishing & Hunting con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fishing & Hunting en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 205/246
# ✅ Obtenidos 47 productos de la categoría Fitness & Exercise Equipment con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Fitness & Exercise Equipment en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 206/246
# ✅ Obtenidos 20 productos de la categoría Game Room con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Game Room en 1262
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 19 productos de la categoría Special Events con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Special Events en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 207/246
# ✅ Obtenidos 60 productos de la categoría Golf con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Golf en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 21 productos de la categoría Beach con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Beach en 1262
# ⏳ Esperando 15s antes del próximo request...
# Completed 208/246
# ✅ Obtenidos 14 productos de la categoría Outdoor Games & Sports Equipment con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Outdoor Games & Sports Equipment en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 209/246
# ✅ Obtenidos 15 productos de la categoría Saunas con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Saunas en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 210/246
# Completed 211/246
# ✅ Obtenidos 94 productos de la categoría Sports Memorabilia & Collectibles con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Sports Memorabilia & Collectibles en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 36 productos de la categoría Tailgating Essentials con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Tailgating Essentials en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 212/246
# Completed 213/246
# ✅ Obtenidos 41 productos de la categoría Water Sports con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Water Sports en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 12 productos de la categoría ATV, Golf & Trailer Tires con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría ATV, Golf & Trailer Tires en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 214/246
# ✅ Obtenidos 51 productos de la categoría Auto & Truck Accessories con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Auto & Truck Accessories en 1262
# ⏳ Esperando 20s antes del próximo request...
# Completed 215/246
# Completed 216/246
# ✅ Obtenidos 12 productos de la categoría Car Electronics con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Car Electronics en 1262
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 12 productos de la categoría Garage & Shop Accessories con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Garage & Shop Accessories en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 217/246
# Completed 218/246
# ✅ Obtenidos 7 productos de la categoría Garage Flooring con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Garage Flooring en 1262
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 12 productos de la categoría Interstate Car & Truck Batteries con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Interstate Car & Truck Batteries en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 219/246
# Completed 220/246
# ✅ Obtenidos 18 productos de la categoría Motor Oil con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Motor Oil en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 1 productos de la categoría Tires con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Tires en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 221/246
# ✅ Obtenidos 14 productos de la categoría Wash & Wax con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wash & Wax en 1262
# ⏳ Esperando 28s antes del próximo request...
# Completed 222/246
# Completed 223/246
# Completed 224/246
# ✅ Obtenidos 1 productos de la categoría Wheels con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wheels en 1262
# ⏳ Esperando 12s antes del próximo request...
# ✅ Obtenidos 1 productos de la categoría Arts, Crafts & Hobby con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Arts, Crafts & Hobby en 1262
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 13 productos de la categoría Building Blocks & Sets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Building Blocks & Sets en 1262
# ⏳ Esperando 10s antes del próximo request...
# Completed 225/246
# ✅ Obtenidos 1 productos de la categoría Dolls & Action Figures con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dolls & Action Figures en 1262
# ⏳ Esperando 15s antes del próximo request...
# Completed 226/246
# ✅ Obtenidos 4 productos de la categoría Dress Up & Pretend Play con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Dress Up & Pretend Play en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 227/246
# Completed 228/246
# ✅ Obtenidos 16 productos de la categoría Outdoor & Water Toys con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Outdoor & Water Toys en 1262
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 5 productos de la categoría Puzzles, Cards & Board Games con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Puzzles, Cards & Board Games en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 229/246
# Completed 230/246
# ✅ Obtenidos 1 productos de la categoría Ride-On Toys con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Ride-On Toys en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 3 productos de la categoría Stuffed Animals & Plush Toys con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Stuffed Animals & Plush Toys en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 231/246
# ✅ Obtenidos 6 productos de la categoría Join Costco con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Join Costco en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 232/246
# ✅ Obtenidos 2 productos de la categoría Black Friday con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Black Friday en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 233/246
# ✅ Obtenidos 1 productos de la categoría Buying Guides con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Buying Guides en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 234/246
# Completed 235/246
# Completed 236/246
# ✅ Obtenidos 3 productos de la categoría Costco Hearing Aid Center con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Costco Hearing Aid Center en 1262
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 9 productos de la categoría Costco Services for Members con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Costco Services for Members en 1262
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 1 productos de la categoría Cyber Monday con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cyber Monday en 1262
# ⏳ Esperando 11s antes del próximo request...
# Completed 237/246
# ✅ Obtenidos 1 productos de la categoría Explore Our Brands con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Explore Our Brands en 1262
# ⏳ Esperando 27s antes del próximo request...
# Completed 238/246
# ✅ Obtenidos 9 productos de la categoría Funeral con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Funeral en 1262
# ⏳ Esperando 26s antes del próximo request...
# Completed 239/246
# ✅ Obtenidos 100 productos de la categoría New Items con skip 0 en 1262
# ⏳ Esperando 13s antes del próximo request...
# Completed 240/246
# ✅ Obtenidos 1 productos de la categoría Pharmacy con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pharmacy en 1262
# ⏳ Esperando 24s antes del próximo request...
# Completed 241/246
# Completed 242/246
# Completed 243/246
# ✅ Obtenidos 100 productos de la categoría New Items con skip 100 en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 244/246
# Completed 245/246
# ✅ Obtenidos 33 productos de la categoría New Items con skip 200 en 1262
# 🛑 Ya no hay más productos para la categoría New Items en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 246/246
# Finished fetching item info.
# Starting products-parsing...
# Parsed 11693 items.

# %%
def fetch_prices_for_stores(df_categories, store_ids, max_workers=5):
    prices_list = []
    tasks = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        for store_id in store_ids:
            print(f'Fetching prices for store {store_id}...')
            for _, row in df_categories.iterrows():
                tasks.append(executor.submit(fetch_products_in_category, row, store_id))

        for i, future in enumerate(concurrent.futures.as_completed(tasks)):
            try:
                result = future.result()
                prices_list.extend(result)
                print(f'Completed {i+1}/{len(tasks)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching prices for all stores.')
    return prices_list



def parse_prices_data(responses_list):
    print('Starting prices-parsing...')
    prices_dict_list = []
    for product in responses_list:
        product_id = product.get('id', None)
        list_price = product.get('item_location_pricing_listPrice', None)
        unit_price = product.get('item_location_pricing_pricePerUnit_price', None)
        sale_price = product.get('item_location_pricing_salePrice', None)
        satus = product.get('item_location_stockStatus', None)
        store_id = product.get('item_location_locationNumber', None)
        item_dict = {
            'product_id': product_id,
            'status': satus,
            'list_price': list_price,
            'unit_price': unit_price,
            'sale_price': sale_price,
            'store_id': store_id
        }
        
        prices_dict_list.append(item_dict)
        

    print(f'Parsed {len(item_dict_list)} items.')
    return prices_dict_list


stores_ids = ['1249', '1235', '1332']
prices_info_list = fetch_prices_for_stores(df_categories, stores_ids, 6)
prices_dict_list = parse_prices_data(prices_info_list)
df_prices = pd.DataFrame( prices_dict_list )
df_prices.to_csv('costco_precios.csv', index=False)
# Out:
# Fetching prices for store 1249...
# Fetching prices for store 1235...
# Fetching prices for store 1332...
# ✅ Obtenidos 10 productos de la categoría Commercial & Restaurant Appliances con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Commercial & Restaurant Appliances en 1249
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 25 productos de la categoría Freezers & Ice Makers con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Freezers & Ice Makers en 1249
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 21 productos de la categoría Kitchen Appliance Packages con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Kitchen Appliance Packages en 1249
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 46 productos de la categoría Dishwashers con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Dishwashers en 1249
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 57 productos de la categoría Heating, Cooling & Air Quality con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Heating, Cooling & Air Quality en 1249
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Cooking Appliances con skip 0 en 1249
# ⏳ Esperando 18s antes del próximo request...
# Completed 1/738
# ✅ Obtenidos 23 productos de la categoría Microwaves con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Microwaves en 1249
# ⏳ Esperando 14s antes del próximo request...
# Completed 2/738
# ✅ Obtenidos 19 productos de la categoría Cooking Appliances con skip 100 en 1249
# 🛑 Ya no hay más productos para la categoría Cooking Appliances en 1249
# ⏳ Esperando 16s antes del próximo request...
# Completed 3/738
# ✅ Obtenidos 93 productos de la categoría Small Kitchen Appliances con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Small Kitchen Appliances en 1249
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Refrigerators con skip 0 en 1249
# ⏳ Esperando 11s antes del próximo request...
# Completed 4/738
# ✅ Obtenidos 16 productos de la categoría Small Space Appliances con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Small Space Appliances en 1249
# ⏳ Esperando 15s antes del próximo request...
# Completed 5/738
# ✅ Obtenidos 49 productos de la categoría Vacuums & Floor Cleaning con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Vacuums & Floor Cleaning en 1249
# ⏳ Esperando 20s antes del próximo request...
# Completed 6/738
# ✅ Obtenidos 46 productos de la categoría Refrigerators con skip 100 en 1249
# 🛑 Ya no hay más productos para la categoría Refrigerators en 1249
# ⏳ Esperando 11s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 0 en 1249
# ⏳ Esperando 18s antes del próximo request...
# Completed 7/738
# ✅ Obtenidos 18 productos de la categoría Wine Coolers & Beverage Refrigerators con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Wine Coolers & Beverage Refrigerators en 1249
# ⏳ Esperando 16s antes del próximo request...
# Completed 8/738
# ✅ Obtenidos 6 productos de la categoría Baby Care & Safety con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Baby Care & Safety en 1249
# ⏳ Esperando 25s antes del próximo request...
# Completed 9/738
# ✅ Obtenidos 12 productos de la categoría Baby Diapers, Wipes & Training Pants con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Baby Diapers, Wipes & Training Pants en 1249
# ⏳ Esperando 27s antes del próximo request...
# Completed 10/738
# ✅ Obtenidos 15 productos de la categoría Baby Formula & Feeding con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Baby Formula & Feeding en 1249
# ⏳ Esperando 21s antes del próximo request...
# Completed 11/738
# ✅ Obtenidos 1 productos de la categoría Car & Booster Seats con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Car & Booster Seats en 1249
# ⏳ Esperando 30s antes del próximo request...
# Completed 12/738
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 100 en 1249
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 15 productos de la categoría Nursery & Baby Furniture con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Nursery & Baby Furniture en 1249
# ⏳ Esperando 16s antes del próximo request...
# Completed 13/738
# ✅ Obtenidos 15 productos de la categoría Bath & Body con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Bath & Body en 1249
# ⏳ Esperando 16s antes del próximo request...
# Completed 14/738
# ✅ Obtenidos 11 productos de la categoría Beauty Gift Sets con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Beauty Gift Sets en 1249
# ⏳ Esperando 29s antes del próximo request...
# Completed 15/738
# Completed 16/738
# ✅ Obtenidos 3 productos de la categoría Beauty Supplements con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Beauty Supplements en 1249
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 29 productos de la categoría Beauty Tools & Accessories con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Beauty Tools & Accessories en 1249
# ⏳ Esperando 27s antes del próximo request...
# Completed 17/738
# ✅ Obtenidos 53 productos de la categoría Fragrances con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Fragrances en 1249
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Washers & Dryers con skip 200 en 1249
# ⏳ Esperando 26s antes del próximo request...
# Completed 18/738
# ✅ Obtenidos 50 productos de la categoría Hair Care con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Hair Care en 1249
# ⏳ Esperando 28s antes del próximo request...
