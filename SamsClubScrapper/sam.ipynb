# %%
# Fetch Stores
import requests
import pandas as pd
import time
import random
import concurrent.futures

def fetch_stores():
    print("Fetching stores.....")
    headers = {
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'cache-control': 'no-cache',
        'dnt': '1',
        'pragma': 'no-cache',
        'priority': 'u=1, i',
        'referer': 'https://www.samsclub.com/c/grocery/1444?xid=hdr:shop:grocery:shop-all-grocery',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        # 'cookie': 'vtc=WMeJdPNy-POKnQF5BYZnrI; _pxvid=f02044f2-251d-11f0-952d-157fb156af83; __pxvid=f050fa61-251d-11f0-8942-86a66639a78a; astract=ca-2dc3cc3b-5930-4447-a814-41953053bd84; _gcl_au=1.1.1093752868.1745947097; s_ecid=MCMID%7C70359388204554853792960967550523055889; _mibhv=anon-1745947103368-7463844918_4591; rmStore=dmid:8096; _fbp=fb.1.1745947103631.19054645703899412; _tt_enable_cookie=1; _ttp=01JT18X4WEQC63J8TQH3ESRYAY_.tt.1; _pin_unauth=dWlkPU5XSmhZV1UxTURndFlqVXdNUzAwWkdWbExXSmtORFF0T0dGbU56azJOMlprTjJaaw; QuantumMetricUserID=fdf19414edfad1d01952bd396fad9725; crl8.fpcuid=f9541edb-6052-4eba-99d2-3a5b8fd396e1; myPreferredClub=6328; myPreferredClubName=Cicero%2C+IL; acstkn=69:16#642671743#7=958758690_1745947557560; sxp-rl-SAT_CME-rn=22; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-rn=76; sxp-rl-SAT_GEO_LOC-rn=80; sxp-rl-SAT_NEW_ORDERS_UI-rn=86; sxp-rl-SAT_ORDER_REPLACEMENT-rn=89; sxp-rl-SAT_REORDER_V4-rn=6; sxp-rl-SCR_CANCEL_ORDER_V3-rn=69; sxp-rl-SCR_CANRV4-rn=76; sxp-rl-SCR_NEXT3-rn=55; sxp-rl-SCR_OHLIMIT-rn=79; sxp-rl-SCR_SHAPEJS-rn=85; sxp-rl-SCR_VERIFICATION_V4-rn=1; sxp-rl-SAT_ADD_ITEM-rn=71; sxp-rl-SCR_RYE-rn=10; sxp-rl-SCR_SCRE-rn=7; sxp-rl-SCR_TII-rn=40; SAT_WPWCNP=1; bstc=RX7qaLdm9-NYUPc1uXiy_Y; xpa=03TBK|b1USw; exp-ck=03TBK2; SAT_CHATBOT=1; sxp-rl-SAT_CME-c=r|1|100; SAT_CME=1; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-c=r|1|0; SAT_DISABLE_SYN_PREQUALIFY=0; sxp-rl-SAT_GEO_LOC-c=r|1|50; SAT_GEO_LOC
jS68sWZFtya5jTO7Jpm8G/m5o217Ckfqd1Ryy7ok6WWlPrf64t1KOeym7jzE9HQ==:1000:ofkD9vb5/SWm4tdTDvW88dwsTZe8TYfm9d3sCg9rTFwEC3AaoNnlcQtEVsBcIzaZXAxBU5etnnXmMWMyvwhF2CpK2XnrjlhYykEHLP3L0mY6Rd0oMb58ZeazBQFfclwClyj4oVWxD1CYxTqOmPTcnJqkxENTyiEFrHLpdas0I52FTEs2fVO8+1u/o0w6bfTQLIN8OMUD82BlGTcnSWUy8mPROVNLE4mnzez872f82fo=; _pxde=a4970ca927ee92a8fd1d68bda653a5a353c7c7c596fd9757c3870a4b14086a56:eyJ0aW1lc3RhbXAiOjE3NDYzODIyMDAyOTl9; akavpau_P1_Sitewide=1746382943~id=3ee96a273d10b282892f06661d36141a; bm_sv=F4326EEB472773D0C43BB3D64EBD56D7~~1; ttcsid_C95MTH3C77U5QKC67MB0=1746381213647::Tf75l4CNA_EIZWa_LQHT.3.1746382343244; s_sq=samclub3prod%3D%2526c.%2526a.%2526activitymap.%2526page%253Dcat%25253Agrocery%2526link%253DFind%2526region%253DBODY%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c%2526pid%253Dcat%25253Agrocery%2526pidt%253D1%2526oid%253DFind%2526oidt%253D3%2526ot%253DSUBMIT',
    }

    params = {
        'distance': '100',
        'nbrOfStores': '20',
        'singleLineAddr': 'florida',
    }

    response = requests.get(
        'https://www.samsclub.com/api/node/vivaldi/browse/v2/clubfinder/list',
        params=params,
        headers=headers,
    )
    
    response.raise_for_status()  # Raise an error for bad responses

    stores_data = response.json()

    stores_dict_list = []
    
    for store in stores_data:
        store_dict = {
            'store_id': store.get('id', None),
            'address': store.get('address', None).get('address1', None),
            'city': store.get('address', None).get('city', None),
            'state': store.get('address', None).get('state', None),
            'zip_code': store.get('address', None).get('postalCode', None),
            'latitude': store.get('geoPoint', None).get('latitude', None),
            'longitude': store.get('geoPoint', None).get('longitude', None),
        }
        stores_dict_list.append(store_dict) 
    stores_df = pd.DataFrame(stores_dict_list)
    stores_df.drop_duplicates(subset='store_id', inplace=True)
    print("Finished fetching stores.")
    return stores_df

df_stores = fetch_stores()

if df_stores is not None:
    df_stores.to_csv('stores.csv', index=False)
    print("Stores data saved to stores.csv")
# Out:
# Fetching stores.....
# Finished fetching stores.
# Stores data saved to stores.csv

# %%
# Fetch Categories
from bs4 import BeautifulSoup
import json
def fetch_categories():
    headers = {
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
            'cache-control': 'max-age=0',
            'dnt': '1',
            'priority': 'u=0, i',
            'referer': 'https://www.samsclub.com/b/mothers-day-meals/2173?xid=cat1444-groc_subcat_1_1',
            'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'document',
            'sec-fetch-mode': 'navigate',
            'sec-fetch-site': 'same-origin',
            'sec-fetch-user': '?1',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
            # 'cookie': 'vtc=WMeJdPNy-POKnQF5BYZnrI; _pxvid=f02044f2-251d-11f0-952d-157fb156af83; __pxvid=f050fa61-251d-11f0-8942-86a66639a78a; astract=ca-2dc3cc3b-5930-4447-a814-41953053bd84; _gcl_au=1.1.1093752868.1745947097; s_ecid=MCMID%7C70359388204554853792960967550523055889; _mibhv=anon-1745947103368-7463844918_4591; rmStore=dmid:8096; _fbp=fb.1.1745947103631.19054645703899412; _tt_enable_cookie=1; _ttp=01JT18X4WEQC63J8TQH3ESRYAY_.tt.1; _pin_unauth=dWlkPU5XSmhZV1UxTURndFlqVXdNUzAwWkdWbExXSmtORFF0T0dGbU56azJOMlprTjJaaw; QuantumMetricUserID=fdf19414edfad1d01952bd396fad9725; crl8.fpcuid=f9541edb-6052-4eba-99d2-3a5b8fd396e1; sxp-rl-SAT_CME-rn=22; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-rn=76; sxp-rl-SAT_GEO_LOC-rn=80; sxp-rl-SAT_NEW_ORDERS_UI-rn=86; sxp-rl-SAT_ORDER_REPLACEMENT-rn=89; sxp-rl-SAT_REORDER_V4-rn=6; sxp-rl-SCR_CANCEL_ORDER_V3-rn=69; sxp-rl-SCR_CANRV4-rn=76; sxp-rl-SCR_NEXT3-rn=55; sxp-rl-SCR_OHLIMIT-rn=79; sxp-rl-SCR_SHAPEJS-rn=85; sxp-rl-SCR_VERIFICATION_V4-rn=1; sxp-rl-SAT_ADD_ITEM-rn=71; sxp-rl-SCR_RYE-rn=10; sxp-rl-SCR_SCRE-rn=7; sxp-rl-SCR_TII-rn=40; SAT_WPWCNP=1; bstc=RX7qaLdm9-NYUPc1uXiy_Y; xpa=03TBK|b1USw; exp-ck=03TBK2; SAT_CHATBOT=1; sxp-rl-SAT_CME-c=r|1|100; SAT_CME=1; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-c=r|1|0; SAT_DISABLE_SYN_PREQUALIFY=0; sxp-rl-SAT_GEO_LOC-c=r|1|50; SAT_GEO_LOC=0; sxp-rl-SAT_NEW_ORDERS_UI-c=r|1|0; SAT_NEW_ORDERS_UI=0; sxp-rl-SAT_ORDER_REPLACEMENT-c=r|1|0; SAT_ORDER_REPLACEMENT=0; sxp-rl-SAT_REORDER_V4-c=r|1|0; SAT_REORDER_V4=0; sxp-rl-SCR_CANCEL_ORDER_V3-c=r|1|0; SCR_CANCEL_ORDER_V3=0; sxp-rl-SCR_CANRV4-c=r|1|100; SCR_CANRV4=1; sxp-rl-SCR_NEXT3-c=r|1|100; SCR_NEXT3=1; sxp-rl-SCR_OHLIMIT-c=r|1|0; SCR_OHLIMIT=0; sxp-rl-SCR_SHAPEJS-c=r|1|0; SCR_SHAPEJS=0; sxp-rl-SCR_VERIFICATION_V4-c
0C43BB3D64EBD56D7~~1; _uetsid=b22c2750291011f0860c7135bba86fdb; _uetvid=f4c25ed0251d11f092b195cbd739e64b; smtrrmkr=638819795725093273%5E0196889d-fd29-4d8b-a960-5ebcfb001e72%5E01969c6e-9a57-4d69-9db2-20a3c1f55c3d%5E0%5E89.187.180.56; _pxde=16d382483154716ff15b58d6a49db44bbace76ad0b0c0cf9b0056a259b71b674:eyJ0aW1lc3RhbXAiOjE3NDYzODI3OTY4NjZ9',
        }

    response = requests.get('https://www.samsclub.com/c', headers=headers)
        
    response.raise_for_status()  
    html = response.text  

    soup = BeautifulSoup(html, 'html.parser')

    # Buscar el <script> por id
    script_tag = soup.find('script', {'id': 'tb-djs-wml-redux-state', 'type': 'application/json'})

    # Obtener el contenido como texto
    if script_tag:
        json_str = script_tag.string
        data = json.loads(json_str)
        categories_data = data['opus']['header_page']['response'][1]['modules'][0]['content']['items'][0]
    else:
        print('Script no encontrado')
    
    categories_dict_list = []
    for category in categories_data:
        subcategories = categories_data.get('secondaryItems', [])
        if subcategories:
            for subcategory in subcategories:
                subcategory_dict = {
                    'category_id': subcategory.get('url').split('/')[-1],
                    'category_name': subcategory.get('name'),
                    'total_products': int(subcategory.get('count') or 0)
                }
                categories_dict_list.append(subcategory_dict)

        categories_df = pd.DataFrame(categories_dict_list)
        categories_df.drop_duplicates(subset='category_id', inplace=True)
        print("Finished fetching categories.")
        return categories_df
    

df_categories = fetch_categories()

if df_categories is not None:
    df_categories.to_csv('categories.csv', index=False)
    print("Categories data saved to categories.csv")
# Out:
# Finished fetching categories.
# Categories data saved to categories.csv

# %%
# Fetch Products
LIMIT = 45 

def fetch_products_in_category(row, store_id = '6403'):
    cat_id = row['category_id']
    cat_name = row['category_name']
    
    
    all_products = []
    skip = 0
    headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'cache-control': 'no-cache',
    'dnt': '1',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://www.samsclub.com/c/grocery/1444?xid=hdr:shop:grocery',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'visitorid': 'WMeJdPNy-POKnQF5BYZnrI',
    'cookie': 'vtc=WMeJdPNy-POKnQF5BYZnrI; _pxvid=f02044f2-251d-11f0-952d-157fb156af83; __pxvid=f050fa61-251d-11f0-8942-86a66639a78a; astract=ca-2dc3cc3b-5930-4447-a814-41953053bd84; _gcl_au=1.1.1093752868.1745947097; s_ecid=MCMID%7C70359388204554853792960967550523055889; _mibhv=anon-1745947103368-7463844918_4591; rmStore=dmid:8096; _fbp=fb.1.1745947103631.19054645703899412; _tt_enable_cookie=1; _ttp=01JT18X4WEQC63J8TQH3ESRYAY_.tt.1; _pin_unauth=dWlkPU5XSmhZV1UxTURndFlqVXdNUzAwWkdWbExXSmtORFF0T0dGbU56azJOMlprTjJaaw; QuantumMetricUserID=fdf19414edfad1d01952bd396fad9725; crl8.fpcuid=f9541edb-6052-4eba-99d2-3a5b8fd396e1; myPreferredClub=6328; myPreferredClubName=Cicero%2C+IL; acstkn=69:16#642671743#7=958758690_1745947557560; sxp-rl-SAT_CME-rn=22; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-rn=76; sxp-rl-SAT_GEO_LOC-rn=80; sxp-rl-SAT_NEW_ORDERS_UI-rn=86; sxp-rl-SAT_ORDER_REPLACEMENT-rn=89; sxp-rl-SAT_REORDER_V4-rn=6; sxp-rl-SCR_CANCEL_ORDER_V3-rn=69; sxp-rl-SCR_CANRV4-rn=76; sxp-rl-SCR_NEXT3-rn=55; sxp-rl-SCR_OHLIMIT-rn=79; sxp-rl-SCR_SHAPEJS-rn=85; sxp-rl-SCR_VERIFICATION_V4-rn=1; sxp-rl-SAT_ADD_ITEM-rn=71; sxp-rl-SCR_RYE-rn=10; sxp-rl-SCR_SCRE-rn=7; sxp-rl-SCR_TII-rn=40; SAT_WPWCNP=1; bstc=RX7qaLdm9-NYUPc1uXiy_Y; xpa=03TBK|b1USw; exp-ck=03TBK2; SAT_CHATBOT=1; sxp-rl-SAT_CME-c=r|1|100; SAT_CME=1; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-c=r|1|0; SAT_DISABLE_SYN_PREQUALIFY=0; sxp-rl-SAT_GEO_LOC-c=r|1|50; SAT_GEO_LOC=0; sxp-rl-SAT_NEW_ORDERS_UI-c=r|1|0; SAT_NEW_ORDERS_UI=0; sxp-rl-SAT_ORDER_REPLACEMENT-c=r|1|0; SAT_ORDER_REPLACEMENT=0; sxp-rl-SAT_REORDER_V4-c=r|1|0; SAT_REORDER_V4=0; sxp-rl-SCR_CANCEL_ORDER_V3-c=r|1|0; SCR_CANCEL_ORDER_V3=0; sxp-rl-SCR_CANRV4-c=r|1|100; SCR_CANRV4=1; sxp-rl-SCR_NEXT3-c=r|1|100; SCR_NEXT3=1; sxp-rl-SCR_OHLIMIT-c=r|1|0; SCR_OHLIMIT=0; sxp-rl-SCR_SHAPEJS-c=r|1|0; SCR_SHAPEJS=0; sxp-rl-SCR_VERIFICATION_V4-c=r|1|0; SCR_VERIFICATION_V4=0; sxp-rl-SAT_ADD_ITEM-c=r|1|100; SAT_ADD_ITEM=1; sxp-rl-SCR_RYE-c=r|1|100; SCR_RYE=1; sxp-rl-SCR_SCRE-c=r|1|100; SCR_SCRE=1; sxp-rl-SCR_TII-c=r|1|100; SCR_TII=1; xpm=1%2B1746381204%2BWMeJdPNy-POKnQF5BYZnrI~%2B1; rcs=eF5jYSlN9khKMTAzNDWw0DWzNDDUNUlLNtU1NUm00DU3NzNNNDdMsjAwMePKLSvJTBEwNDc20zXUNQQAfukNfA; sams-pt=eyJ4NXQiOiJzOXN6ZUptWldjMWhRYktIOUVqSmNoOUZkTkEiLCJraWQiOiJCM0RCMzM3OD
            'searchCategoryId': cat_id,
            'clubId': '6328',
            'br': 'true',
            'secondaryResults': '2',
            'wmVideo': 'true',
        }
        
        try:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()
            data = response.json()
            products = data.get('payload',None).get('records', [])
            print(f'Obtenidos {len(products)} productos de la categoría {cat_name} con skip {skip} en {store_id}')
            all_products.extend(products)
            print(f'✅ Obtenidos {len(products)} productos de la categoría {cat_name} con skip {skip} en {store_id}')
        except Exception as e:
            print(f'❌ Error al obtener productos de la categoría {cat_name} con skip {skip} en {store_id}: {e}')
            break

        
        if len(products) < LIMIT:
            print(f'🛑 Ya no hay más productos para la categoría {cat_name} en {store_id}')
            sleep_time = random.randint(10, 45)
            print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
            time.sleep(sleep_time)
            break

        skip += LIMIT

        sleep_time = random.randint(10, 45)
        print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
        time.sleep(sleep_time)

    return all_products


def fetch_all_item_info(df_categories, max_workers=3):
    print('Fetching items info...')
    item_info_list = []
    # Crea el grupo de hilos
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        #Crea las tareas par cada categoria
        futures = [executor.submit(fetch_products_in_category, row, '6403') for _, row in df_categories.iterrows()]
        
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            try:
                result = future.result()
                item_info_list.extend(result)
                print(f'Completed {i+1}/{len(futures)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching item info.')
    return item_info_list



def parse_products_data(responses_list):
    print('Starting products-parsing...')
    item_dict_list = []
    for product in responses_list:
        id = product.get('id')
        name = product.get('descriptors', {}).get('name')
        gtin = product.get('skus', {})[0].get('clubOffer', {}).get("gtin", None) 
        category_id = product.get('category').get('categoryId', None)
        brand = product.get('manufacturingInfo').get('brand', None)
        rating = product.get('reviewsAndRatings', {}).get('avgRating', None)

        item_dict = {
            'id': id,
            'name': name,
            'gtin': gtin,
            'category': category_id,
            'brand': brand,
            'rating': rating,
            
        }

        item_dict_list.append(item_dict)

    print(f'Parsed {len(item_dict_list)} items.')
    return item_dict_list




item_info_list = fetch_all_item_info( df_categories, 3)
item_dict_list = parse_products_data(item_info_list)
df_items = pd.DataFrame(item_dict_list)
df_items.to_csv('productos.csv', index=False)
# Out:
# Fetching items info...
# Obtenidos 45 productos de la categoría Fresh Food con skip 0 en 6403
# ✅ Obtenidos 45 productos de la categoría Fresh Food con skip 0 en 6403
# ⏳ Esperando 38s antes del próximo request...
# Obtenidos 45 productos de la categoría Pantry con skip 0 en 6403
# ✅ Obtenidos 45 productos de la categoría Pantry con skip 0 en 6403
# ⏳ Esperando 23s antes del próximo request...
# Obtenidos 45 productos de la categoría Snacks con skip 0 en 6403
# ✅ Obtenidos 45 productos de la categoría Snacks con skip 0 en 6403
# ⏳ Esperando 37s antes del próximo request...
# Obtenidos 45 productos de la categoría Pantry con skip 45 en 6403
# ✅ Obtenidos 45 productos de la categoría Pantry con skip 45 en 6403
# ⏳ Esperando 39s antes del próximo request...
# Obtenidos 45 productos de la categoría Fresh Food con skip 45 en 6403
# ✅ Obtenidos 45 productos de la categoría Fresh Food con skip 45 en 6403
# ⏳ Esperando 23s antes del próximo request...
# ...

# %%
def fetch_prices_for_stores(df_categories, store_ids, max_workers=5):
    prices_list = []
    tasks = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        for store_id in store_ids:
            print(f'Fetching prices for store {store_id}...')
            for _, row in df_categories.iterrows():
                tasks.append(executor.submit(fetch_products_in_category, row, store_id))

        for i, future in enumerate(concurrent.futures.as_completed(tasks)):
            try:
                result = future.result()
                prices_list.extend(result)
                print(f'Completed {i+1}/{len(tasks)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching prices for all stores.')
    return prices_list



def parse_prices_data(responses_list):
    print('Starting prices-parsing...')
    prices_dict_list = []
    for product in responses_list:
        id = product.get('id')
        name = product.get('descriptors', {}).get('name')
        gtin = product.get('skus', {})[0].get('clubOffer', {}).get("gtin", None) 
        category_id = product.get('category').get('categoryId', None)
        final_price = product.get('skus', {})[0].get('clubOffer', {}).get('price',{}).get('final_price', {}).get('amount', None)
        start_price = product.get('skus', {})[0].get('clubOffer', {}).get('price',{}).get('start_price', {}).get('amount', None)
        unit_price = product.get('skus', {})[0].get('clubOffer', {}).get('price',{}).get('unit_price', {}).get('amount', None)
        satus = product.get('skus', {})[0].get('clubOffer', {}).get('inventory', None).get('status', None)
        store_id = product.get('skus', {})[0].get('clubOffer', {}).get('clubId', None)
        item_dict = {
            'product_id': id,
            'name': name,
            'gtin': gtin,
            'category': category_id,
            'final_price': final_price,
            'start_price': start_price,
            'unit_price': unit_price,
            'status': satus,
            'store_id': store_id
        }
        
        prices_dict_list.append(item_dict)
        

    print(f'Parsed {len(item_dict_list)} items.')
    return prices_dict_list


stores_ids = ['4794', '6441', '4801']
prices_info_list = fetch_prices_for_stores(df_categories, stores_ids, 3)
prices_dict_list = parse_prices_data(prices_info_list)
df_prices = pd.DataFrame( prices_dict_list )
df_prices.to_csv('precios.csv', index=False)
# Out:
# Fetching prices for store 4794...
# Fetching prices for store 6441...
# Fetching prices for store 4801...
# ❌ Error al obtener productos de la categoría Fresh Food con skip 0 en 4794: 412 Client Error: Precondition Failed for url: https://www.samsclub.com/api/node/vivaldi/browse/v2/products/search?sourceType=1&selectedFilter=all&sortKey=relevance&sortOrder=0&limit=45&offset=0&searchType=PRODUCTS&recordType=primary&searchCategoryId=430221&clubId=6328&br=true&secondaryResults=2&wmVideo=true
# Completed 1/69
# ❌ Error al obtener productos de la categoría Pantry con skip 0 en 4794: 412 Client Error: Precondition Failed for url: https://www.samsclub.com/api/node/vivaldi/browse/v2/products/search?sourceType=1&selectedFilter=all&sortKey=relevance&sortOrder=0&limit=45&offset=0&searchType=PRODUCTS&recordType=primary&searchCategoryId=450193&clubId=6328&br=true&secondaryResults=2&wmVideo=true
# Completed 2/69
# ...
