# %%
import requests
import pandas as pd
import time
import random
import concurrent.futures


def fetch_stores():
    print("Fetching stores.....")
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'en-us',
        'Connection': 'keep-alive',
        'DNT': '1',
        'Origin': 'https://www.costco.com',
        'Referer': 'https://www.costco.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'client_id': '45823696-9189-482d-89c3-0c067e477ea1',
        'latitude': '28.6305',
        'longitude': '-82.4497',
        'limit': '50',
        'openingDate': '2025-05-02',
    }
    try: 
        response = requests.get('https://ecom-api.costco.com/warehouseLocatorMobile/v1/warehouses.json', params=params, headers=headers)

        response.raise_for_status()  # Raise an error for bad responses

        data = response.json()

        stores_data = data.get('warehouses', [])
        stores_dict_list = []
        
        for store in stores_data:
            store_dict = {
                'internal_id': store.get('warehouseId'),
                'address': store.get('address', None).get('line1', None),
                'city': store.get('address', None).get('city', None),
                'state': store.get('address', None).get('territory', None),
                'latitude': store.get('address', None).get('latitude', None),
                'longitude': store.get('address', None).get('longitude', None),
            }
            stores_dict_list.append(store_dict) 
        stores_df = pd.DataFrame(stores_dict_list)
        stores_df.drop_duplicates(subset='internal_id', inplace=True)
        print("Finished fetching stores.")
        return stores_df
    except requests.exceptions.RequestException as e:
        print(f"Error fetching stores: {e}")
        return None

# %%
#Fetch Categories

def fetch_categories():
    print("Fetching categories...")
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Connection': 'keep-alive',
        'DNT': '1',
        'Origin': 'https://www.costco.com',
        'Referer': 'https://www.costco.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'x-api-key': '273db6be-f015-4de7-b0d6-dd4746ccd5c3',
    }

    params = {
        'locale': 'en-US',
        'loc': '1250-3pl,1321-wm,1456-3pl,283-wm,561-wm,725-wm,731-wm,758-wm,759-wm,847_0-cor,847_0-cwt,847_0-edi,847_0-ehs,847_0-membership,847_0-mpt,847_0-spc,847_0-wm,847_1-cwt,847_1-edi,847_d-fis,847_lg_n1f-edi,847_NA-cor,847_NA-pharmacy,847_NA-wm,847_ss_u362-edi,847_wp_r458-edi,951-wm,952-wm,9847-wcs,115-bd,1249-wh',
        'chdmegamenu': 'true',
        'userLocation': 'WA',
        'userPostal': '98101',
    }
    try:
        response = requests.get(
            'https://search.costco.com/api/apps/www_costco_com/query/www_costco_com_megamenu',
            params=params,
            headers=headers,
        )

        response.raise_for_status()
        data = response.json()
        categories_data = data.get('megaMenu', {})
        categories_dict_list = []
        for category in categories_data:
            if category.get('name') == 'Grocery & Household Essentials':
                subcategories = category.get('children', [])
                
                if subcategories:
                    for subcategory in subcategories:
                        subcategory_dict = {
                            'internal_id': subcategory.get('url').split('/')[-1],
                            'category_name': subcategory.get('name'),
                            'total_products': int(subcategory.get('count') or 0),
                        }
                        categories_dict_list.append(subcategory_dict)

        categories_df = pd.DataFrame(categories_dict_list)
        categories_df.drop_duplicates(subset='internal_id', inplace=True)
        print("Finished fetching categories.")
        return categories_df
    except requests.exceptions.RequestException as e:
        print(f"Error fetching categories: {e}")
        return None

# %%
# Fetch Products

def fetch_products_in_category(row, store_id = '1262'):
    cat_id = row['internal_id']
    cat_name = row['category_name']
    LIMIT = 100     
    

    all_products = []
    skip = 0
    headers = {
    'Accept': 'application/json',
    'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    'DNT': '1',
    'Origin': 'https://www.costco.com',
    'Referer': 'https://www.costco.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'x-api-key': '273db6be-f015-4de7-b0d6-dd4746ccd5c3',
}


    while True:
        url = (
            'https://search.costco.com/api/apps/www_costco_com/query/www_costco_com_navigation'
            f'?expoption=def&q=*%3A*&locale=en-US&start={skip}&rows={LIMIT}&expand=false&userLocation=WA'
        )
        params = {
            'currenPage': skip // LIMIT, 
            'whloc': f'{store_id}-wh',
            'url': f'/{cat_id}',
            'fq': '{!tag=item_program_eligibility}item_program_eligibility:("InWarehouse")',

        }
        try:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()
            data = response.json()
            products = data.get('response', {}).get('docs', [])
            all_products.extend(products)
            print(f'✅ Obtenidos {len(products)} productos de la categoría {cat_name} con skip {skip} en {store_id}')
        except Exception as e:
            print(f'❌ Error al obtener productos de la categoría {cat_name} con skip {skip} en {store_id}: {e}')
            break

        
        if len(products) < LIMIT:
            print(f'🛑 Ya no hay más productos para la categoría {cat_name} en {store_id}')
            sleep_time = random.randint(10, 30)
            print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
            time.sleep(sleep_time)
            break

        skip += LIMIT

        sleep_time = random.randint(10, 30)
        print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
        time.sleep(sleep_time)

    return all_products



def fetch_all_item_info(df_categories, max_workers=5):
    print('Fetching items info...')
    item_info_list = []
    # Crea el grupo de hilos
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        #Crea las tareas par cada categoria
        futures = [executor.submit(fetch_products_in_category, row, '1262') for _, row in df_categories.iterrows()]
        
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            try:
                result = future.result()
                item_info_list.extend(result)
                print(f'Completed {i+1}/{len(futures)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching item info.')
    return item_info_list



def parse_products_data(responses_list):
    print('Starting products-parsing...')
    item_dict_list = []
    for product in responses_list:
        name = product.get('name')
        id = product.get('id')
        upc_list = product.get('item_manufacturing_skus') or []
        category_path = product.get('categoryPath_ss') or []
        upc = upc_list[0] if upc_list else None
        category_id = category_path[0] if category_path else None
        brand = product.get('Brand_attr')
        weight = product.get('Weight_attr')
        height = product.get('Height_attr')
        width = product.get('Width_attr')
        length = product.get('Length_attr')
        color = product.get('Color_attr')

        item_dict = {
            'internal_id': id,
            'name': name,
            'upc': upc,
            'internal_category_id': category_id,
            'brand': brand,
            'weight': weight,
            'height': height,
            'width': width,
            'length': length,
            'color': color,
        }

        item_dict_list.append(item_dict)

    print(f'Parsed {len(item_dict_list)} items.')
    return item_dict_list

# %%
def fetch_prices_for_stores(df_categories, store_ids, max_workers=5):
    prices_list = []
    tasks = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        for store_id in store_ids:
            print(f'Fetching prices for store {store_id}...')
            for _, row in df_categories.iterrows():
                tasks.append(executor.submit(fetch_products_in_category, row, store_id))

        for i, future in enumerate(concurrent.futures.as_completed(tasks)):
            try:
                result = future.result()
                prices_list.extend(result)
                print(f'Completed {i+1}/{len(tasks)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching prices for all stores.')
    return prices_list



def parse_prices_data(responses_list):
    print('Starting prices-parsing...')
    prices_dict_list = []
    for product in responses_list:
        product_id = product.get('id', None)
        list_price = product.get('item_location_pricing_listPrice', None)
        unit_price = product.get('item_location_pricing_pricePerUnit_price', None)
        sale_price = product.get('item_location_pricing_salePrice', None)
        satus = product.get('item_location_stockStatus', None)
        store_id = product.get('item_location_locationNumber', None)
        store_id = store_id.split('-')[0] if store_id else None
        item_dict = {
            'product_id': product_id,
            'status': satus,
            'list_price': list_price,
            'unit_price': unit_price,
            'sale_price': sale_price,
            'store_id': store_id,
            'date': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S'),
        }
        
        prices_dict_list.append(item_dict)
        

    print(f'Parsed {len(prices_dict_list)} items.')
    return prices_dict_list

# %%
def main():
    # Fetch stores
    df_stores = fetch_stores()
    if df_stores is not None:
        df_stores.to_csv('cotsco_stores.csv', index=False)
        print("Stores data saved to stores.csv")

    # Fetch categories
    df_categories = fetch_categories()
    if df_categories is not None:
        df_categories.to_csv('cotsco_all_categories.csv', index=False)
        print("Categories data saved to categories.csv")

    # Fetch products
    item_info_list = fetch_all_item_info( df_categories, 6)
    item_dict_list = parse_products_data(item_info_list)
    df_items = pd.DataFrame(item_dict_list)
    df_items.to_csv('cotsco_products.csv', index=False)
    
main()
# Out:
# Fetching stores.....
# Finished fetching stores.
# Stores data saved to stores.csv
# Fetching categories...
# Finished fetching categories.
# Categories data saved to categories.csv
# Fetching items info...
# ✅ Obtenidos 0 productos de la categoría Cheese & Dairy con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cheese & Dairy en 1262
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 0 productos de la categoría Bakery & Desserts con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Bakery & Desserts en 1262
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 30 productos de la categoría Beverages & Water con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Beverages & Water en 1262
# ⏳ Esperando 12s antes del próximo request...
# ✅ Obtenidos 8 productos de la categoría Breakfast con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Breakfast en 1262
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 50 productos de la categoría 2-Day Delivery con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría 2-Day Delivery en 1262
# ⏳ Esperando 12s antes del próximo request...
# ✅ Obtenidos 15 productos de la categoría Candy con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Candy en 1262
# ⏳ Esperando 29s antes del próximo request...
# Completed 1/19
# Completed 2/19
# ✅ Obtenidos 22 productos de la categoría Coffee con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Coffee en 1262
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 46 productos de la categoría Cleaning Supplies con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Cleaning Supplies en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 3/19
# ✅ Obtenidos 1 productos de la categoría Deli con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Deli en 1262
# ⏳ Esperando 16s antes del próximo request...
# Completed 4/19
# ✅ Obtenidos 0 productos de la categoría Emergency Food Supplies & Kits con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Emergency Food Supplies & Kits en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 5/19
# Completed 6/19
# ✅ Obtenidos 0 productos de la categoría Gift Baskets con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Gift Baskets en 1262
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Kirkland Signature Grocery con skip 0 en 1262
# ⏳ Esperando 30s antes del próximo request...
# Completed 7/19
# ✅ Obtenidos 0 productos de la categoría Meat & Seafood con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Meat & Seafood en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 8/19
# ✅ Obtenidos 20 productos de la categoría Organic Groceries con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Organic Groceries en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 9/19
# Completed 10/19
# ✅ Obtenidos 77 productos de la categoría Pantry & Dry Goods con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Pantry & Dry Goods en 1262
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 39 productos de la categoría Paper & Plastic Products con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Paper & Plastic Products en 1262
# ⏳ Esperando 17s antes del próximo request...
# Completed 11/19
# ✅ Obtenidos 0 productos de la categoría Same-Day Delivery con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Same-Day Delivery en 1262
# ⏳ Esperando 19s antes del próximo request...
# Completed 12/19
# ✅ Obtenidos 86 productos de la categoría Snacks con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Snacks en 1262
# ⏳ Esperando 23s antes del próximo request...
# Completed 13/19
# ✅ Obtenidos 0 productos de la categoría Wine, Champagne & Sparkling con skip 0 en 1262
# 🛑 Ya no hay más productos para la categoría Wine, Champagne & Sparkling en 1262
# ⏳ Esperando 12s antes del próximo request...
# Completed 14/19
# Completed 15/19
# Completed 16/19
# ✅ Obtenidos 5 productos de la categoría Kirkland Signature Grocery con skip 100 en 1262
# 🛑 Ya no hay más productos para la categoría Kirkland Signature Grocery en 1262
# ⏳ Esperando 14s antes del próximo request...
# Completed 17/19
# Completed 18/19
# Completed 19/19
# Finished fetching item info.
# Starting products-parsing...
# Parsed 499 items.

# %%
def prices():
    # Fetch prices
    stores_ids = ['1249', '1235', '1332']
    df_categories = fetch_categories()
    prices_info_list = fetch_prices_for_stores(df_categories, stores_ids, 6)
    prices_dict_list = parse_prices_data(prices_info_list)
    df_prices = pd.DataFrame( prices_dict_list )
    df_prices.to_csv('cotsco_item_prices_17_05.csv', index=False)
    
prices()
# Out:
# Fetching categories...
# Finished fetching categories.
# Fetching prices for store 1249...
# Fetching prices for store 1235...
# Fetching prices for store 1332...
# ✅ Obtenidos 0 productos de la categoría Bakery & Desserts con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Bakery & Desserts en 1249
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Candy con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Candy en 1249
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 0 productos de la categoría Cheese & Dairy con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Cheese & Dairy en 1249
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 8 productos de la categoría Breakfast con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Breakfast en 1249
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 49 productos de la categoría 2-Day Delivery con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría 2-Day Delivery en 1249
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 31 productos de la categoría Beverages & Water con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Beverages & Water en 1249
# ⏳ Esperando 14s antes del próximo request...
# Completed 1/57
# ✅ Obtenidos 46 productos de la categoría Cleaning Supplies con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Cleaning Supplies en 1249
# ⏳ Esperando 16s antes del próximo request...
# Completed 2/57
# Completed 3/57
# ✅ Obtenidos 1 productos de la categoría Deli con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Deli en 1249
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 22 productos de la categoría Coffee con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Coffee en 1249
# ⏳ Esperando 28s antes del próximo request...
# Completed 4/57
# ✅ Obtenidos 0 productos de la categoría Emergency Food Supplies & Kits con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Emergency Food Supplies & Kits en 1249
# ⏳ Esperando 18s antes del próximo request...
# Completed 5/57
# ✅ Obtenidos 0 productos de la categoría Gift Baskets con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Gift Baskets en 1249
# ⏳ Esperando 14s antes del próximo request...
# Completed 6/57
# ✅ Obtenidos 100 productos de la categoría Kirkland Signature Grocery con skip 0 en 1249
# ⏳ Esperando 20s antes del próximo request...
# Completed 7/57
# ✅ Obtenidos 0 productos de la categoría Meat & Seafood con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Meat & Seafood en 1249
# ⏳ Esperando 14s antes del próximo request...
# Completed 8/57
# Completed 9/57
# ✅ Obtenidos 20 productos de la categoría Organic Groceries con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Organic Groceries en 1249
# ⏳ Esperando 19s antes del próximo request...
# Completed 10/57
# ✅ Obtenidos 38 productos de la categoría Paper & Plastic Products con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Paper & Plastic Products en 1249
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 76 productos de la categoría Pantry & Dry Goods con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Pantry & Dry Goods en 1249
# ⏳ Esperando 17s antes del próximo request...
# Completed 11/57
# ✅ Obtenidos 0 productos de la categoría Same-Day Delivery con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Same-Day Delivery en 1249
# ⏳ Esperando 21s antes del próximo request...
# Completed 12/57
# ✅ Obtenidos 86 productos de la categoría Snacks con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Snacks en 1249
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 6 productos de la categoría Kirkland Signature Grocery con skip 100 en 1249
# 🛑 Ya no hay más productos para la categoría Kirkland Signature Grocery en 1249
# ⏳ Esperando 24s antes del próximo request...
# Completed 13/57
# Completed 14/57
# ✅ Obtenidos 0 productos de la categoría Wine, Champagne & Sparkling con skip 0 en 1249
# 🛑 Ya no hay más productos para la categoría Wine, Champagne & Sparkling en 1249
# ⏳ Esperando 11s antes del próximo request...
# ✅ Obtenidos 48 productos de la categoría 2-Day Delivery con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría 2-Day Delivery en 1235
# ⏳ Esperando 14s antes del próximo request...
# Completed 15/57
# ✅ Obtenidos 0 productos de la categoría Bakery & Desserts con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Bakery & Desserts en 1235
# ⏳ Esperando 22s antes del próximo request...
# Completed 16/57
# Completed 17/57
# ✅ Obtenidos 8 productos de la categoría Breakfast con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Breakfast en 1235
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 31 productos de la categoría Beverages & Water con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Beverages & Water en 1235
# ⏳ Esperando 18s antes del próximo request...
# Completed 18/57
# ✅ Obtenidos 16 productos de la categoría Candy con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Candy en 1235
# ⏳ Esperando 11s antes del próximo request...
# Completed 19/57
# ✅ Obtenidos 0 productos de la categoría Cheese & Dairy con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Cheese & Dairy en 1235
# ⏳ Esperando 29s antes del próximo request...
# Completed 20/57
# ✅ Obtenidos 47 productos de la categoría Cleaning Supplies con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Cleaning Supplies en 1235
# ⏳ Esperando 18s antes del próximo request...
# Completed 21/57
# ✅ Obtenidos 23 productos de la categoría Coffee con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Coffee en 1235
# ⏳ Esperando 29s antes del próximo request...
# Completed 22/57
# ✅ Obtenidos 1 productos de la categoría Deli con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Deli en 1235
# ⏳ Esperando 26s antes del próximo request...
# Completed 23/57
# ✅ Obtenidos 0 productos de la categoría Emergency Food Supplies & Kits con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Emergency Food Supplies & Kits en 1235
# ⏳ Esperando 11s antes del próximo request...
# Completed 24/57
# ✅ Obtenidos 0 productos de la categoría Gift Baskets con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Gift Baskets en 1235
# ⏳ Esperando 24s antes del próximo request...
# Completed 25/57
# ✅ Obtenidos 100 productos de la categoría Kirkland Signature Grocery con skip 0 en 1235
# ⏳ Esperando 19s antes del próximo request...
# Completed 26/57
# ✅ Obtenidos 0 productos de la categoría Meat & Seafood con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Meat & Seafood en 1235
# ⏳ Esperando 23s antes del próximo request...
# Completed 27/57
# ✅ Obtenidos 19 productos de la categoría Organic Groceries con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Organic Groceries en 1235
# ⏳ Esperando 10s antes del próximo request...
# Completed 28/57
# Completed 29/57
# ✅ Obtenidos 40 productos de la categoría Paper & Plastic Products con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Paper & Plastic Products en 1235
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 75 productos de la categoría Pantry & Dry Goods con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Pantry & Dry Goods en 1235
# ⏳ Esperando 21s antes del próximo request...
# Completed 30/57
# ✅ Obtenidos 0 productos de la categoría Same-Day Delivery con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Same-Day Delivery en 1235
# ⏳ Esperando 14s antes del próximo request...
# ✅ Obtenidos 4 productos de la categoría Kirkland Signature Grocery con skip 100 en 1235
# 🛑 Ya no hay más productos para la categoría Kirkland Signature Grocery en 1235
# ⏳ Esperando 26s antes del próximo request...
# Completed 31/57
# ✅ Obtenidos 84 productos de la categoría Snacks con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Snacks en 1235
# ⏳ Esperando 14s antes del próximo request...
# Completed 32/57
# ✅ Obtenidos 0 productos de la categoría Wine, Champagne & Sparkling con skip 0 en 1235
# 🛑 Ya no hay más productos para la categoría Wine, Champagne & Sparkling en 1235
# ⏳ Esperando 10s antes del próximo request...
# Completed 33/57
# Completed 34/57
# ✅ Obtenidos 0 productos de la categoría Bakery & Desserts con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Bakery & Desserts en 1332
# ⏳ Esperando 13s antes del próximo request...
# ✅ Obtenidos 50 productos de la categoría 2-Day Delivery con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría 2-Day Delivery en 1332
# ⏳ Esperando 16s antes del próximo request...
# Completed 35/57
# ✅ Obtenidos 30 productos de la categoría Beverages & Water con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Beverages & Water en 1332
# ⏳ Esperando 30s antes del próximo request...
# Completed 36/57
# Completed 37/57
# ✅ Obtenidos 8 productos de la categoría Breakfast con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Breakfast en 1332
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Candy con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Candy en 1332
# ⏳ Esperando 27s antes del próximo request...
# Completed 38/57
# ✅ Obtenidos 0 productos de la categoría Cheese & Dairy con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Cheese & Dairy en 1332
# ⏳ Esperando 20s antes del próximo request...
# Completed 39/57
# ✅ Obtenidos 47 productos de la categoría Cleaning Supplies con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Cleaning Supplies en 1332
# ⏳ Esperando 26s antes del próximo request...
# Completed 40/57
# ✅ Obtenidos 22 productos de la categoría Coffee con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Coffee en 1332
# ⏳ Esperando 11s antes del próximo request...
# Completed 41/57
# ✅ Obtenidos 1 productos de la categoría Deli con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Deli en 1332
# ⏳ Esperando 11s antes del próximo request...
# Completed 42/57
# ✅ Obtenidos 0 productos de la categoría Emergency Food Supplies & Kits con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Emergency Food Supplies & Kits en 1332
# ⏳ Esperando 21s antes del próximo request...
# Completed 43/57
# Completed 44/57
# ✅ Obtenidos 0 productos de la categoría Gift Baskets con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Gift Baskets en 1332
# ⏳ Esperando 15s antes del próximo request...
# Completed 45/57
# ✅ Obtenidos 0 productos de la categoría Meat & Seafood con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Meat & Seafood en 1332
# ⏳ Esperando 14s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Kirkland Signature Grocery con skip 0 en 1332
# ⏳ Esperando 21s antes del próximo request...
# Completed 46/57
# ✅ Obtenidos 19 productos de la categoría Organic Groceries con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Organic Groceries en 1332
# ⏳ Esperando 17s antes del próximo request...
# Completed 47/57
# ✅ Obtenidos 76 productos de la categoría Pantry & Dry Goods con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Pantry & Dry Goods en 1332
# ⏳ Esperando 25s antes del próximo request...
# Completed 48/57
# Completed 49/57
# ✅ Obtenidos 0 productos de la categoría Same-Day Delivery con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Same-Day Delivery en 1332
# ⏳ Esperando 14s antes del próximo request...
# ✅ Obtenidos 38 productos de la categoría Paper & Plastic Products con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Paper & Plastic Products en 1332
# ⏳ Esperando 24s antes del próximo request...
# Completed 50/57
# ✅ Obtenidos 84 productos de la categoría Snacks con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Snacks en 1332
# ⏳ Esperando 22s antes del próximo request...
# Completed 51/57
# ✅ Obtenidos 0 productos de la categoría Wine, Champagne & Sparkling con skip 0 en 1332
# 🛑 Ya no hay más productos para la categoría Wine, Champagne & Sparkling en 1332
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 2 productos de la categoría Kirkland Signature Grocery con skip 100 en 1332
# 🛑 Ya no hay más productos para la categoría Kirkland Signature Grocery en 1332
# ⏳ Esperando 13s antes del próximo request...
# Completed 52/57
# Completed 53/57
# Completed 54/57
# Completed 55/57
# Completed 56/57
# Completed 57/57
# Finished fetching prices for all stores.
# Starting prices-parsing...
# Parsed 1486 items.
