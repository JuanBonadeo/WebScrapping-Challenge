# %%
# Fetch Stores

import requests
import pandas as pd
import time
import random
import concurrent.futures
import json

def fetch_stores():
    cookies = {
        'csm-sid': '918-1782596-5487095',
        'cwr_u': '64f3bde1-cb48-4a14-87f2-9a4fdcd59116',
        'session-id': '135-5565599-9128112',
        'session-id-time': '2082787201l',
        '_gcl_au': '1.1.940198342.1745948856',
        'ubid-main': '135-4690566-1873008',
        'wfm_store_d8': '',
        'session-token': '',
        'cwr_s': '...',
    }
    
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        'Content-Type': 'application/json; charset=utf-8',
        'DNT': '1',
        'Origin': 'https://www.wholefoodsmarket.com',
        'Pragma': 'no-cache',
        'Referer': 'https://www.wholefoodsmarket.com/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'anti-csrftoken-a2z': 'gwvPkdVTZCot5RmVuZnSmXs8B+T3DK0Cf+T1FX2vZ5tuAAAAAQAAAABoES4JcmF3AAAAACr/Igfie4qiUf9rqj+gAw==',
        'device-memory': '8',
        'downlink': '4.15',
        'dpr': '1.25',
        'ect': '4g',
        'rtt': '200',
        'sec-ch-device-memory': '8',
        'sec-ch-dpr': '1.25',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-ch-ua-platform-version': '"15.0.0"',
        'sec-ch-viewport-width': '712',
        'viewport-width': '712',
        # 'Cookie': 'csm-sid=918-1782596-5487095; cwr_u=64f3bde1-cb48-4a14-87f2-9a4fdcd59116; session-id=135-5565599-9128112; session-id-time=2082787201l; _gcl_au=1.1.940198342.1745948856; ubid-main=135-4690566-1873008; wfm_store_d8=; session-token=; cwr_s=...',
    }
    
    json_data = {
        'query': [
            '...',
        ],
    }
    try:
        response = requests.post('https://www.wholefoodsmarket.com/stores/search', cookies=cookies, headers=headers, json=json_data)
        response.raise_for_status()  # Raise an error for bad responses
        stores_json_response = response.json()
        
        stores_dict_list = []
        
        stores_data = stores_json_response
        for store in stores_data:
            store_dict = {
            'address' : store['location']['address']['line1'],
            'state' : store['location']['address']['state'],
            'city' : store['location']['address']['city'],
            'latitude' : store['location']['geometry']['coordinates'][0],
            'longitude' : store['location']['geometry']['coordinates'][1],
            'store_id' : store['storeId'],
            }
            stores_dict_list.append(store_dict) 
        stores_df = pd.DataFrame(stores_dict_list)
        stores_df.drop_duplicates(subset='store_id', inplace=True)
        print("Finished fetching stores.")
        return stores_df
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return 

df_stores = fetch_stores()

if df_stores is not None:
    df_stores.to_csv('stores.csv', index=False)
    print("Stores data saved to stores.csv")
# Out:
# Finished fetching stores.
# Stores data saved to stores.csv

# %%
# Fetch Categories

def fetch_categories():
    cookies = {
        'csm-sid': '918-1782596-5487095',
        'cwr_u': '64f3bde1-cb48-4a14-87f2-9a4fdcd59116',
        'session-id': '135-5565599-9128112',
        'session-id-time': '2082787201l',
        '_gcl_au': '1.1.940198342.1745948856',
        'ubid-main': '135-4690566-1873008',
        'wfm_store_d8': '',
        'session-token': '',
        'cwr_s': '...',
    }
    
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        'DNT': '1',
        'Pragma': 'no-cache',
        'Referer': 'https://www.wholefoodsmarket.com/products',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'device-memory': '8',
        'downlink': '10',
        'dpr': '1',
        'ect': '4g',
        'rtt': '150',
        'sec-ch-device-memory': '8',
        'sec-ch-dpr': '1',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-ch-ua-platform-version': '"15.0.0"',
        'sec-ch-viewport-width': '1865',
        'viewport-width': '1865',
        'x-nextjs-data': '1',
    }
    
    params = {
        'store': '10478',
    }
    
    response = requests.get(
        'https://www.wholefoodsmarket.com/_next/data/Ncw9ULavm0ZnyLSw84ld-/products.json',
        params=params,
        cookies=cookies,
        headers=headers,
    )
    
    response_json = response.json()
    
    categories_data = response_json['pageProps']['data']['facets'][0]['refinements']
    
    categories_dict_list = []

    
    for category in categories_data:
        if category['slug'] != 'all-products':
            category_dict = {
            'category_id': category['slug'],
            'category_name': category['label'],
            'total_products': int(category['count'])
            }
            categories_dict_list.append(category_dict)
        
    categories_df = pd.DataFrame(categories_dict_list)
    categories_df.drop_duplicates(subset='category_id', inplace=True)
    print("Finished fetching categories.")
    return categories_df

df_categories = fetch_categories()

if df_categories is not None:
    df_categories.to_csv('categories.csv', index=False)
    print("Categories data saved to categories.csv")
# Out:
# Finished fetching categories.
# Categories data saved to categories.csv

# %% [markdown]
# openfoots

# %%
# Fetch products

def fetch_products_in_category(row, store_id):
    cat_id = row['category_id']
    total_products = row['total_products']
    cat_name = row['category_name']

    headers = {
        'Accept': '*/*',
        'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Connection': 'keep-alive',
        'Content-Type': 'application/json',
        'DNT': '1',
        'Referer': f'https://www.wholefoodsmarket.com/products/{cat_id}',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'credentials': 'include',
        'device-memory': '8',
        'downlink': '9.95',
        'dpr': '1',
        'ect': '4g',
        'rtt': '150',
        'sec-ch-device-memory': '8',
        'sec-ch-dpr': '1',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-ch-ua-platform-version': '"15.0.0"',
        'sec-ch-viewport-width': '1865',
        'viewport-width': '1865',
        # 'Cookie': 'csm-sid=918-1782596-5487095; cwr_u=64f3bde1-cb48-4a14-87f2-9a4fdcd59116; session-id=135-5565599-9128112; session-id-time=2082787201l; _gcl_au=1.1.940198342.1745948856; ubid-main=135-4690566-1873008; session-token=; wfm_store_d8=; cwr_s=',
    }
    
    cookies = {
        'csm-sid': '918-1782596-5487095',
        'cwr_u': '64f3bde1-cb48-4a14-87f2-9a4fdcd59116',
        'session-id': '135-5565599-9128112',
        'session-id-time': '2082787201l',
        '_gcl_au': '1.1.940198342.1745948856',
        'ubid-main': '135-4690566-1873008',
        'session-token': '',
        'wfm_store_d8': '',
        'cwr_s': '',
    }
    all_products = []
    skip = 0
    LIMIT = 60
    
    
    while True:
        params = {
            'leafCategory': cat_id,
            'store': store_id,
            'limit': str(LIMIT),
            'offset': str(skip),
        }
        try:
            response = requests.get(f'https://www.wholefoodsmarket.com/api/products/category/{cat_id}',params=params,cookies=cookies,headers=headers,)
            response.raise_for_status()
            data = response.json()
            products = data.get('results', [])
            all_products.extend(products)
            print(f'✅ Obtenidos {len(products)} productos de la categoría {cat_name} con skip {skip}')
        except Exception as e:
            print(f'❌ Error al obtener productos de la categoría {cat_name} con skip {skip}: {e}')
            break

        # Si recibimos menos productos que el límite, ya no hay más productos
        if len(products) < LIMIT:
            print(f'🛑 Ya no hay más productos para la categoría {cat_name}')
            break

        skip += LIMIT

        # Pausa aleatoria para no abusar del servidor
        sleep_time = random.randint(15, 35)
        print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
        time.sleep(sleep_time)

    return all_products



def fetch_all_item_info(df_categories, max_workers=5):
    print('Fetching items info...')
    item_info_list = []
    # Crea el grupo de hilos
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        #Crea las tareas par cada categoria
        futures = [executor.submit(fetch_products_in_category, row, '10478') for _, row in df_categories.iterrows()]
        
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            try:
                result = future.result()
                item_info_list.extend(result)
                print(f'Completed {i+1}/{len(futures)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching item info.')
    return item_info_list



def parse_item_data(responses_list):
    print('Starting item-parsing...')
    item_dict_list = []

    for product in responses_list:
        brand = product.get('brand', None)
        image_thumbnail = product.get('imageThumbnail', None)
        is_local = product.get('isLocal', None)
        name = product.get('name', None)
        slug = product.get('slug', None)
        uom = product.get('uom', None)
        
        # Extraer ASIN del slug (última parte después del último '-')
        asin = slug.split('-')[-1] if slug else None

        item_dict = {
            'brand': brand,
            'image_thumbnail': image_thumbnail,
            'is_local': is_local,
            'name': name,
            'slug': slug,
            'uom': uom,
            'asin': asin 
        }

        item_dict_list.append(item_dict)
    
    print(f'Parsed {len(item_dict_list)} items.') 
    df_items = pd.DataFrame(item_dict_list)
    return df_items


item_info_list = fetch_all_item_info( df_categories)
df_items = parse_item_data(item_info_list)

# Guardar los datos en un CSV
df_items.to_csv('productos.csv', index=False)
# Out:
# Fetching items info...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 0
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Prepared Foods con skip 0
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 0
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 0
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 60
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 60
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 60
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 60
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 19 productos de la categoría Prepared Foods con skip 60
# 🛑 Ya no hay más productos para la categoría Prepared Foods
# Completed 1/20
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 120
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 120
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 120
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 60
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 180
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Meat con skip 180
# 🛑 Ya no hay más productos para la categoría Meat
# Completed 2/20
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 0
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 180
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 180
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 120
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 240
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 60
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 240
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Produce con skip 240
# 🛑 Ya no hay más productos para la categoría Produce
# Completed 3/20
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 180
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 300
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 60
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 360
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 21 productos de la categoría Breads, Rolls & Bakery con skip 240
# 🛑 Ya no hay más productos para la categoría Breads, Rolls & Bakery
# Completed 4/20
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 0
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 300
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 24 productos de la categoría Desserts con skip 180
# 🛑 Ya no hay más productos para la categoría Desserts
# Completed 5/20
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 0
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 120
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 60
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 420
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 360
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 120
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 60
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 480
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 180
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 420
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 180
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 240
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 540
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 180
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 480
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 240
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 300
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 300
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 600
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 240
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 540
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 360
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 360
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Dairy & Eggs con skip 660
# 🛑 Ya no hay más productos para la categoría Dairy & Eggs
# Completed 6/20
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 0
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 600
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 420
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 300
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 60
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 420
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 660
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 360
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 480
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 720
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 480
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 120
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 420
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 780
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 540
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 540
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 180
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 600
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 9 productos de la categoría Frozen Foods con skip 480
# 🛑 Ya no hay más productos para la categoría Frozen Foods
# Completed 7/20
# ✅ Obtenidos 12 productos de la categoría Seafood con skip 0
# 🛑 Ya no hay más productos para la categoría Seafood
# Completed 8/20
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 840
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 0
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 600
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 240
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 900
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 60
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 300
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 660
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Body Care con skip 660
# 🛑 Ya no hay más productos para la categoría Body Care
# Completed 9/20
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 0
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 960
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 17 productos de la categoría Supplements con skip 720
# 🛑 Ya no hay más productos para la categoría Supplements
# Completed 10/20
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 0
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1020
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 360
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 60
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 60
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 180
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 420
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1080
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 120
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 480
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 240
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1140
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 180
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 180
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 240
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 540
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 240
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1200
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 300
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 300
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1260
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 300
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 600
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 360
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 420
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1320
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 360
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 660
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 360
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1380
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 480
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 720
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 420
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1440
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 420
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 780
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 540
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Beauty con skip 480
# 🛑 Ya no hay más productos para la categoría Beauty
# Completed 11/20
# ✅ Obtenidos 22 productos de la categoría Floral con skip 0
# 🛑 Ya no hay más productos para la categoría Floral
# Completed 12/20
# ✅ Obtenidos 60 productos de la categoría Household con skip 0
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 840
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1500
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 600
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 40 productos de la categoría Wine, Beer & Spirits con skip 480
# 🛑 Ya no hay más productos para la categoría Wine, Beer & Spirits
# Completed 13/20
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 0
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 900
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1560
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Household con skip 60
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 660
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 38 productos de la categoría Household con skip 120
# 🛑 Ya no hay más productos para la categoría Household
# Completed 14/20
# ✅ Obtenidos 60 productos de la categoría Lifestyle con skip 0
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 60
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 960
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1620
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 720
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Lifestyle con skip 60
# 🛑 Ya no hay más productos para la categoría Lifestyle
# Completed 15/20
# ✅ Obtenidos 60 productos de la categoría Pet con skip 0
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Snacks, Chips, Salsas & Dips con skip 1020
# 🛑 Ya no hay más productos para la categoría Snacks, Chips, Salsas & Dips
# Completed 16/20
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1680
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 45 productos de la categoría Baby & Child con skip 120
# 🛑 Ya no hay más productos para la categoría Baby & Child
# Completed 17/20
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 780
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1740
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 26 productos de la categoría Pet con skip 60
# 🛑 Ya no hay más productos para la categoría Pet
# Completed 18/20
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 840
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1800
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 37 productos de la categoría Beverages con skip 900
# 🛑 Ya no hay más productos para la categoría Beverages
# Completed 19/20
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1860
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1920
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1980
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2040
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2100
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2160
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 2 productos de la categoría Pantry Essentials con skip 2220
# 🛑 Ya no hay más productos para la categoría Pantry Essentials
# Completed 20/20
# Finished fetching item info.
# Starting item-parsing...

# %%
# Fetch prices for stores

def fetch_prices_for_stores(df_categories, store_ids, max_workers=5):
    prices_list = []
    tasks = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:

        for store_id in store_ids:
            print(f'Fetching prices for store {store_id}...')
            for _, row in df_categories.iterrows():
                tasks.append(executor.submit(fetch_products_in_category, row, store_id))

        for i, future in enumerate(concurrent.futures.as_completed(tasks)):
            try:
                result = future.result()
                prices_list.extend(result)
                print(f'Completed {i+1}/{len(tasks)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching prices for all stores.')
    return prices_list



def parse_prices_data(responses_list):
    print('Starting prices-parsing...')
    prices_dict_list = []
    
    for product in responses_list:
        name = product.get('name', None)
        regular_price = product.get('regularPrice', None)
        slug = product.get('slug', None)
        store = product.get('store', None)
        item_dict = {
            'name': name,
            'regular_price': regular_price,
            'slug': slug,
            'store': store,
        }
        
        prices_dict_list.append(item_dict)
        
    print(f'Parsed {len(item_dict_list)} items.')
    return prices_dict_list



stores_ids = ['10478','10704','10621']
prices_info_list = fetch_prices_for_stores(df_categories, stores_ids, 5)
prices_dict_list = parse_prices_data(prices_info_list)

# Guardar los datos en un CSV
df_prices = pd.DataFrame(prices_dict_list)
df_prices.to_csv('precios.csv', index=False)
# Out:
# Fetching prices for store 10478...
# Fetching prices for store 10704...
# Fetching prices for store 10621...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 0
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 0
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Prepared Foods con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 0
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 0
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 19 productos de la categoría Prepared Foods con skip 60
# 🛑 Ya no hay más productos para la categoría Prepared Foods
# Completed 1/60
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 0
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 60
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 60
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 60
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 60
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 120
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 60
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 120
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 120
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 180
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 180
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 120
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 180
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Meat con skip 180
# 🛑 Ya no hay más productos para la categoría Meat
# Completed 2/60
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 0
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 180
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Produce con skip 240
# 🛑 Ya no hay más productos para la categoría Produce
# Completed 3/60
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 0
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 240
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 21 productos de la categoría Breads, Rolls & Bakery con skip 240
# 🛑 Ya no hay más productos para la categoría Breads, Rolls & Bakery
# Completed 4/60
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 60
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 240
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 60
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 120
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 60
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 300
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 300
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 360
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 120
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 360
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 24 productos de la categoría Desserts con skip 180
# 🛑 Ya no hay más productos para la categoría Desserts
# Completed 5/60
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 0
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 180
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 180
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 420
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 240
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 60
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 420
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 240
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 480
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 480
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 300
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 300
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 120
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 540
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 540
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 360
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 360
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 600
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 180
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 420
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 420
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 600
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 240
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 480
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 660
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 480
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Dairy & Eggs con skip 660
# 🛑 Ya no hay más productos para la categoría Dairy & Eggs
# Completed 6/60
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 0
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 300
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 720
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 540
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 540
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 360
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 60
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 600
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 600
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 780
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 120
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 420
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 660
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Body Care con skip 660
# 🛑 Ya no hay más productos para la categoría Body Care
# Completed 7/60
# ✅ Obtenidos 12 productos de la categoría Seafood con skip 0
# 🛑 Ya no hay más productos para la categoría Seafood
# Completed 8/60
# ✅ Obtenidos 9 productos de la categoría Frozen Foods con skip 480
# 🛑 Ya no hay más productos para la categoría Frozen Foods
# Completed 9/60
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 0
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 180
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 840
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 17 productos de la categoría Supplements con skip 720
# 🛑 Ya no hay más productos para la categoría Supplements
# Completed 10/60
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 0
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 60
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 60
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 240
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 120
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 900
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 60
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 300
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 120
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 120
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 180
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 180
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 360
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 960
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 240
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 180
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 240
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1020
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 300
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 420
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 240
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 480
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 300
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 360
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1080
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 300
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 540
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 420
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 360
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1140
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 360
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 600
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 420
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1200
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 40 productos de la categoría Wine, Beer & Spirits con skip 480
# 🛑 Ya no hay más productos para la categoría Wine, Beer & Spirits
# Completed 11/60
# ✅ Obtenidos 22 productos de la categoría Floral con skip 0
# 🛑 Ya no hay más productos para la categoría Floral
# Completed 12/60
# ✅ Obtenidos 60 productos de la categoría Household con skip 0
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 420
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Household con skip 60
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Beauty con skip 480
# 🛑 Ya no hay más productos para la categoría Beauty
# Completed 13/60
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 0
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 660
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1260
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 480
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 60
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1320
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 720
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 38 productos de la categoría Household con skip 120
# 🛑 Ya no hay más productos para la categoría Household
# Completed 14/60
# ✅ Obtenidos 60 productos de la categoría Lifestyle con skip 0
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 45 productos de la categoría Baby & Child con skip 120
# 🛑 Ya no hay más productos para la categoría Baby & Child
# Completed 15/60
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 540
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pet con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1380
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 780
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Lifestyle con skip 60
# 🛑 Ya no hay más productos para la categoría Lifestyle
# Completed 16/60
# ✅ Obtenidos 60 productos de la categoría Produce con skip 0
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 600
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 26 productos de la categoría Pet con skip 60
# 🛑 Ya no hay más productos para la categoría Pet
# Completed 17/60
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 840
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 60
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1440
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 60
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 900
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 660
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 120
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 960
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1500
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 180
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 720
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 180
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 11 productos de la categoría Snacks, Chips, Salsas & Dips con skip 1020
# 🛑 Ya no hay más productos para la categoría Snacks, Chips, Salsas & Dips
# Completed 18/60
# ✅ Obtenidos 60 productos de la categoría Meat con skip 0
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1560
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 780
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 240
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 240
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 60
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1620
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 4 productos de la categoría Produce con skip 300
# 🛑 Ya no hay más productos para la categoría Produce
# Completed 19/60
# ✅ Obtenidos 60 productos de la categoría Prepared Foods con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 840
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 300
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 120
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1680
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 52 productos de la categoría Prepared Foods con skip 60
# 🛑 Ya no hay más productos para la categoría Prepared Foods
# Completed 20/60
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 360
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 0
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 37 productos de la categoría Beverages con skip 900
# 🛑 Ya no hay más productos para la categoría Beverages
# Completed 21/60
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 0
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 420
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1740
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 180
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 60
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1800
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 60
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 480
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 120
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 0 productos de la categoría Meat con skip 240
# 🛑 Ya no hay más productos para la categoría Meat
# Completed 22/60
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 0
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 540
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 180
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1860
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 120
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 60
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 600
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 120
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1920
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 240
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 180
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 38 productos de la categoría Desserts con skip 180
# 🛑 Ya no hay más productos para la categoría Desserts
# Completed 23/60
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 0
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 47 productos de la categoría Dairy & Eggs con skip 660
# 🛑 Ya no hay más productos para la categoría Dairy & Eggs
# Completed 24/60
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 0
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1980
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 29 productos de la categoría Breads, Rolls & Bakery con skip 240
# 🛑 Ya no hay más productos para la categoría Breads, Rolls & Bakery
# Completed 25/60
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 0
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 300
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 60
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 60
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 60
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 360
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2040
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 120
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2100
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 180
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 420
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 180
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 180
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 240
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 480
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2160
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 240
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 240
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 300
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 2 productos de la categoría Pantry Essentials con skip 2220
# 🛑 Ya no hay más productos para la categoría Pantry Essentials
# Completed 26/60
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 540
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 300
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 360
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 300
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 60
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 600
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 360
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 420
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 360
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 660
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 120
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 420
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 480
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 180
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 420
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 540
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 26 productos de la categoría Frozen Foods con skip 480
# 🛑 Ya no hay más productos para la categoría Frozen Foods
# Completed 27/60
# ✅ Obtenidos 23 productos de la categoría Seafood con skip 0
# 🛑 Ya no hay más productos para la categoría Seafood
# Completed 28/60
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 720
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 0
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 240
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 780
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 300
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 600
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 480
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 60
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 46 productos de la categoría Supplements con skip 660
# 🛑 Ya no hay más productos para la categoría Supplements
# Completed 29/60
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 0
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 120
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 840
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 360
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 60
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 900
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 540
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 420
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 180
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 960
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 600
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 480
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 240
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 120
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1020
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 2 productos de la categoría Body Care con skip 660
# 🛑 Ya no hay más productos para la categoría Body Care
# Completed 30/60
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 0
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 540
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 300
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 180
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 600
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 360
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 60
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1080
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 660
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 240
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 420
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 120
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1140
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 720
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 480
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 180
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1200
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 300
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 540
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 240
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 780
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 600
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1260
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 53 productos de la categoría Wine, Beer & Spirits con skip 360
# 🛑 Ya no hay más productos para la categoría Wine, Beer & Spirits
# Completed 31/60
# ✅ Obtenidos 16 productos de la categoría Floral con skip 0
# 🛑 Ya no hay más productos para la categoría Floral
# Completed 32/60
# ✅ Obtenidos 60 productos de la categoría Household con skip 0
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 300
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1320
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 840
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 660
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 720
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Household con skip 60
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1380
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 900
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 360
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 780
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 42 productos de la categoría Household con skip 120
# 🛑 Ya no hay más productos para la categoría Household
# Completed 33/60
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 0
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1440
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 420
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 840
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 960
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1500
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 60
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1560
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 10 productos de la categoría Beauty con skip 480
# 🛑 Ya no hay más productos para la categoría Beauty
# Completed 34/60
# ✅ Obtenidos 6 productos de la categoría Snacks, Chips, Salsas & Dips con skip 1020
# 🛑 Ya no hay más productos para la categoría Snacks, Chips, Salsas & Dips
# Completed 35/60
# ✅ Obtenidos 60 productos de la categoría Lifestyle con skip 0
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pet con skip 0
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 22 productos de la categoría Beverages con skip 900
# 🛑 Ya no hay más productos para la categoría Beverages
# Completed 36/60
# ✅ Obtenidos 60 productos de la categoría Produce con skip 0
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 120
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 39 productos de la categoría Pet con skip 60
# 🛑 Ya no hay más productos para la categoría Pet
# Completed 37/60
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1620
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 60
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Lifestyle con skip 60
# 🛑 Ya no hay más productos para la categoría Lifestyle
# Completed 38/60
# ✅ Obtenidos 60 productos de la categoría Meat con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 4 productos de la categoría Baby & Child con skip 180
# 🛑 Ya no hay más productos para la categoría Baby & Child
# Completed 39/60
# ✅ Obtenidos 60 productos de la categoría Prepared Foods con skip 0
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 60
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 52 productos de la categoría Prepared Foods con skip 60
# 🛑 Ya no hay más productos para la categoría Prepared Foods
# Completed 40/60
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 0
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 120
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 60
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1680
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Meat con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 120
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Produce con skip 180
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 60
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1740
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 31 productos de la categoría Meat con skip 180
# 🛑 Ya no hay más productos para la categoría Meat
# Completed 41/60
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 0
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 180
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 38 productos de la categoría Produce con skip 240
# 🛑 Ya no hay más productos para la categoría Produce
# Completed 42/60
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 120
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 0
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1800
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 180
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 60
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 60
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 240
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1860
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 240
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 120
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Desserts con skip 120
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 300
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 300
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1920
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Breads, Rolls & Bakery con skip 180
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 27 productos de la categoría Desserts con skip 180
# 🛑 Ya no hay más productos para la categoría Desserts
# Completed 43/60
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 0
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 360
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 360
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 21 productos de la categoría Breads, Rolls & Bakery con skip 240
# 🛑 Ya no hay más productos para la categoría Breads, Rolls & Bakery
# Completed 44/60
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 0
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1980
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 60
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 420
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 420
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 60
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 120
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 480
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 480
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2040
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 120
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 180
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 540
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2100
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 540
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 240
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 180
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 300
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Dairy & Eggs con skip 600
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 240
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2160
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 600
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 360
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 43 productos de la categoría Dairy & Eggs con skip 660
# 🛑 Ya no hay más productos para la categoría Dairy & Eggs
# Completed 45/60
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 300
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 0
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 660
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 22 productos de la categoría Pantry Essentials con skip 2220
# 🛑 Ya no hay más productos para la categoría Pantry Essentials
# Completed 46/60
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 0
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 420
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 360
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 720
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 60
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 60
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 420
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 780
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 480
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 840
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 120
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 540
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 480
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 180
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 180
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 240
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 900
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 540
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Body Care con skip 600
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 240
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 960
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 300
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Supplements con skip 600
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1020
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Body Care con skip 660
# 🛑 Ya no hay más productos para la categoría Body Care
# Completed 47/60
# ✅ Obtenidos 17 productos de la categoría Seafood con skip 0
# 🛑 Ya no hay más productos para la categoría Seafood
# Completed 48/60
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 0
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 300
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 360
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 51 productos de la categoría Supplements con skip 660
# 🛑 Ya no hay más productos para la categoría Supplements
# Completed 49/60
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 0
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1080
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 60
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Frozen Foods con skip 420
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 120
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 360
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 60
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Frozen Foods con skip 480
# 🛑 Ya no hay más productos para la categoría Frozen Foods
# Completed 50/60
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1140
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 0
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 420
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 180
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 480
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 240
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 60
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1200
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 120
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 180
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1260
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 300
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 540
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1320
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 180
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 240
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 360
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1380
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 600
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 240
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 300
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 420
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1440
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 660
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 300
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 360
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1500
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 480
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beauty con skip 360
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 720
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Wine, Beer & Spirits con skip 420
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 540
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 49 productos de la categoría Beauty con skip 420
# 🛑 Ya no hay más productos para la categoría Beauty
# Completed 51/60
# ✅ Obtenidos 19 productos de la categoría Floral con skip 0
# 🛑 Ya no hay más productos para la categoría Floral
# Completed 52/60
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1560
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Household con skip 0
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 780
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 27 productos de la categoría Wine, Beer & Spirits con skip 480
# 🛑 Ya no hay más productos para la categoría Wine, Beer & Spirits
# Completed 53/60
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 0
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 600
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1620
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Household con skip 60
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 840
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 60
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 660
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 49 productos de la categoría Household con skip 120
# 🛑 Ya no hay más productos para la categoría Household
# Completed 54/60
# ✅ Obtenidos 60 productos de la categoría Lifestyle con skip 0
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 900
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1680
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Baby & Child con skip 120
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 35 productos de la categoría Lifestyle con skip 60
# 🛑 Ya no hay más productos para la categoría Lifestyle
# Completed 55/60
# ✅ Obtenidos 60 productos de la categoría Pet con skip 0
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 5 productos de la categoría Baby & Child con skip 180
# 🛑 Ya no hay más productos para la categoría Baby & Child
# Completed 56/60
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 720
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Snacks, Chips, Salsas & Dips con skip 960
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1740
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 27 productos de la categoría Pet con skip 60
# 🛑 Ya no hay más productos para la categoría Pet
# Completed 57/60
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 780
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1800
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 4 productos de la categoría Snacks, Chips, Salsas & Dips con skip 1020
# 🛑 Ya no hay más productos para la categoría Snacks, Chips, Salsas & Dips
# Completed 58/60
# ✅ Obtenidos 60 productos de la categoría Beverages con skip 840
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1860
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1920
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 0 productos de la categoría Beverages con skip 900
# 🛑 Ya no hay más productos para la categoría Beverages
# Completed 59/60
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 1980
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 60 productos de la categoría Pantry Essentials con skip 2040
# ⏳ Esperando 25s antes del próximo request...
