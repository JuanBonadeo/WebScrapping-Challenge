# %%
import requests
import pandas as pd
import time
import random
import concurrent.futures

def fetch_stores():
    print("Fetching stores.....")
    headers = {
        'sec-ch-ua-platform': '"Windows"',
        'Referer': 'https://www.sedanos.com/store-locator',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
        'Accept': 'application/json, text/javascript, */*; q=0.01',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'DNT': '1',
        'sec-ch-ua-mobile': '?0',
    }
    
    params = {
        'app_key': 'sedanos',
        'has_address': 'true',
        'limit': '-1',
        'token': 'cb1b0701f3e646bbe5c9e0518addcfc4',
    }
    
    response = requests.get('https://api.freshop.com/1/stores', params=params, headers=headers)
    
    stores_json_response = response.json()
    
    stores_dict_list = []
    
    stores_data = stores_json_response['items']
    for store in stores_data:
        store_dict = {
        'address' : store['address_1'],
        'city' : store['city'],
        'latitude' : store['longitude'],
        'longitude' : store['latitude'],
        'store_id' : store['id'],
        'store_number' : store['store_number'],
        }
        stores_dict_list.append(store_dict) 
    stores_df = pd.DataFrame(stores_dict_list)
    stores_df.drop_duplicates(subset='store_number', inplace=True)
    print("Finished fetching stores.")
    return stores_df


df_stores = fetch_stores()

if df_stores is not None:
    df_stores.to_csv('stores.csv', index=False)
    print("Stores data saved to stores.csv")
# Out:
# Fetching stores.....
# Finished fetching stores.
# Stores data saved to stores.csv

# %%
# Fetch Categories
def fetch_categories():
    print("Fetching categories...")
    headers = {
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'dnt': '1',
        'origin': 'https://www.sedanos.com',
        'priority': 'u=1, i',
        'referer': 'https://www.sedanos.com/shop/catering/d/22571166',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'cross-site',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    }
    
    params = {
        'app_key': 'sedanos',
        'custom_filter_id_cascade': 'false',
        'department_id_cascade': 'false',
        'include_custom_filters': 'false',
        'include_departments': 'true',
        'include_offered_together': 'true',
        'include_shelf_tags': 'false',
        'include_tags': 'false',
        'limit': '0',
        'render_id': '1745762834459',
        'token': 'cb1b0701f3e646bbe5c9e0518addcfc4',
    }
    
    response = requests.get('https://api.freshop.com/1/products', params=params, headers=headers)
    
    categories_json_response = response.json()
    
    categories_dict_list = []
    
    categories_data = categories_json_response['departments']
    
    for category in categories_data:
        if (category.get('parent_id', None) == '22394611' and category.get('id') != '22394619'):
            category_dict = {
            'category_id': category['id'],
            'category_name': category['name'],
            'total_products': int(category['count'])
            }
            categories_dict_list.append(category_dict)
        
    categories_df = pd.DataFrame(categories_dict_list)
    categories_df.drop_duplicates(subset='category_id', inplace=True)
    print("Finished fetching categories.")
    return categories_df


df_categories = fetch_categories()

if df_categories is not None:
    df_categories.to_csv('categories.csv', index=False)
    print("Categories data saved to categories.csv")
# Out:
# Fetching categories...
# Finished fetching categories.
# Categories data saved to categories.csv

# %%
# Fetch Products
LIMIT = 100  

def fetch_products_in_category(row, store_id, token='cb1b0701f3e646bbe5c9e0518addcfc4'):
    cat_id = row['category_id']
    total_products = row['total_products']
    cat_name = row['category_name']
    headers = {
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'dnt': '1',
        'origin': 'https://www.sedanos.com',
        'priority': 'u=1, i',
        'referer': f'https://www.sedanos.com/shop/{cat_name}/d/{cat_id}',
        'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'cross-site',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    }

    all_products = []
    skip = 0

    while True:
        params = {
            'app_key': 'sedanos',
            'department_id': cat_id,
            'department_id_cascade': 'true',
            'fields': 'id, identifier, upc, name, store_id, department_id, size,popularity, canonical_url, varieties,quantity_size_ratio_description,status,status_id,other_attributes,average_rating,review_count,unit_price,offer_sale_price',  
            'include_offered_together': 'true',
            'limit': str(LIMIT),
            'popularity_sort': 'asc',
            'render_id': '1745763999375',
            'sort': 'popularity',
            'store_id': store_id,
            'token': token,
            'skip': str(skip),
        }

        try:
            response = requests.get('https://api.freshop.com/1/products', params=params, headers=headers)
            response.raise_for_status()
            data = response.json()
            products = data.get('items', [])
            all_products.extend(products)
            print(f'✅ Obtenidos {len(products)} productos de la categoría {cat_name} con skip {skip} en {store_id}')
        except Exception as e:
            print(f'❌ Error al obtener productos de la categoría {cat_name} con skip {skip} en {store_id}: {e}')
            break

        
        if len(products) < LIMIT:
            print(f'🛑 Ya no hay más productos para la categoría {cat_name} en {store_id}')
            break

        skip += LIMIT

        sleep_time = random.randint(15, 35)
        print(f'⏳ Esperando {sleep_time}s antes del próximo request...')
        time.sleep(sleep_time)

    return all_products



def fetch_all_item_info(df_categories, max_workers=5):
    print('Fetching items info...')
    item_info_list = []
    # Crea el grupo de hilos
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        #Crea las tareas par cada categoria
        futures = [executor.submit(fetch_products_in_category, row, '5761') for _, row in df_categories.iterrows()]
        
        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            try:
                result = future.result()
                item_info_list.extend(result)
                print(f'Completed {i+1}/{len(futures)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching item info.')
    return item_info_list



def parse_products_data(responses_list):
    print('Starting products-parsing...')
    item_dict_list = []
    for product in responses_list:
        name = product.get('name', None)
        id = product.get('id', None)
        upc = product.get('upc', None)
        category_id = product.get('department_id')
        size = product.get('size', None)
        url = product.get('canonical_url', None)
        status = product.get('status', None)
        

        item_dict = {
            'id': id,
            'name': name,
            'upc': upc,
            'category': category_id,
            'size': size,
            'url': url,
            'status': status,
        }
        
        item_dict_list.append(item_dict)
        

    print(f'Parsed {len(item_dict_list)} items.')
    return item_dict_list


item_info_list = fetch_all_item_info( df_categories, 5)
item_dict_list = parse_products_data(item_info_list)
df_items = pd.DataFrame(item_dict_list)
df_items.to_csv('productos.csv', index=False)
# Out:
# Fetching items info...
# ✅ Obtenidos 100 productos de la categoría Deli con skip 0 en 5761
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 0 en 5761
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 0 en 5761
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 0 en 5761
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 0 en 5761
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Deli con skip 100 en 5761
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 100 en 5761
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 100 en 5761
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 100 en 5761
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 100 en 5761
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 57 productos de la categoría Deli con skip 200 en 5761
# 🛑 Ya no hay más productos para la categoría Deli en 5761
# Completed 1/21
# ✅ Obtenidos 100 productos de la categoría Home & Floral con skip 0 en 5761
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 200 en 5761
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 200 en 5761
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 72 productos de la categoría Bakery con skip 200 en 5761
# 🛑 Ya no hay más productos para la categoría Bakery en 5761
# Completed 2/21
# ✅ Obtenidos 100 productos de la categoría Meat con skip 0 en 5761
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 200 en 5761
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 6 productos de la categoría Home & Floral con skip 100 en 5761
# 🛑 Ya no hay más productos para la categoría Home & Floral en 5761
# Completed 3/21
# ✅ Obtenidos 100 productos de la categoría Produce con skip 0 en 5761
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 84 productos de la categoría Beer, Wine & Spirits con skip 300 en 5761
# 🛑 Ya no hay más productos para la categoría Beer, Wine & Spirits en 5761
# Completed 4/21
# ✅ Obtenidos 100 productos de la categoría Meat con skip 100 en 5761
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 77 productos de la categoría Seafood con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Seafood en 5761
# Completed 5/21
# ✅ Obtenidos 61 productos de la categoría Catering con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Catering en 5761
# Completed 6/21
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 300 en 5761
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 4 productos de la categoría Weekly BOGO con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Weekly BOGO en 5761
# Completed 7/21
# ✅ Obtenidos 14 productos de la categoría Meals on a Budget con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Meals on a Budget en 5761
# Completed 8/21
# ✅ Obtenidos 88 productos de la categoría Organic con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Organic en 5761
# Completed 9/21
# ✅ Obtenidos 100 productos de la categoría Produce con skip 100 en 5761
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 300 en 5761
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 0 en 5761
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 200 en 5761
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 400 en 5761
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 100 en 5761
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 400 en 5761
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 97 productos de la categoría Produce con skip 200 en 5761
# 🛑 Ya no hay más productos para la categoría Produce en 5761
# Completed 10/21
# ✅ Obtenidos 62 productos de la categoría Charcuterie Board Items con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Charcuterie Board Items en 5761
# Completed 11/21
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 0 en 5761
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 300 en 5761
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 500 en 5761
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 500 en 5761
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 200 en 5761
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 100 en 5761
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 40 productos de la categoría Meat con skip 400 en 5761
# 🛑 Ya no hay más productos para la categoría Meat en 5761
# Completed 12/21
# ✅ Obtenidos 7 productos de la categoría Nestle Deal con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Nestle Deal en 5761
# Completed 13/21
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 600 en 5761
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 29 productos de la categoría Build Your Own Smoothie con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Build Your Own Smoothie en 5761
# Completed 14/21
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 600 en 5761
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 64 productos de la categoría Quick Meals con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Quick Meals en 5761
# Completed 15/21
# ✅ Obtenidos 4 productos de la categoría Pan con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Pan en 5761
# Completed 16/21
# ✅ Obtenidos 48 productos de la categoría Fair Essentials con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Fair Essentials en 5761
# Completed 17/21
# ✅ Obtenidos 30 productos de la categoría Sedano's Brand con skip 300 en 5761
# 🛑 Ya no hay más productos para la categoría Sedano's Brand en 5761
# Completed 18/21
# ✅ Obtenidos 56 productos de la categoría Frozen Foods con skip 700 en 5761
# 🛑 Ya no hay más productos para la categoría Frozen Foods en 5761
# Completed 19/21
# ✅ Obtenidos 65 productos de la categoría Dairy con skip 700 en 5761
# 🛑 Ya no hay más productos para la categoría Dairy en 5761
# Completed 20/21
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 200 en 5761
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 300 en 5761
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 400 en 5761
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 88 productos de la categoría Compare and Save con skip 500 en 5761
# 🛑 Ya no hay más productos para la categoría Compare and Save en 5761
# Completed 21/21
# Finished fetching item info.
# Starting products-parsing...
# Parsed 4653 items.

# %%
def fetch_prices_for_stores(df_categories, store_ids, max_workers=5):
    prices_list = []
    tasks = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        for store_id in store_ids:
            print(f'Fetching prices for store {store_id}...')
            for _, row in df_categories.iterrows():
                tasks.append(executor.submit(fetch_products_in_category, row, store_id))

        for i, future in enumerate(concurrent.futures.as_completed(tasks)):
            try:
                result = future.result()
                prices_list.extend(result)
                print(f'Completed {i+1}/{len(tasks)}')
            except Exception as e:
                print(f"Error in thread: {e}")

    print('Finished fetching prices for all stores.')
    return prices_list



def parse_prices_data(responses_list):
    print('Starting prices-parsing...')
    prices_dict_list = []
    for product in responses_list:
        product_id = product.get('id', None)
        unit_price = product.get('unit_price', None)
        sale_price = product.get('offer_sale_price', None)
        store_id = product.get('store_id', None)
        item_dict = {
            'product_id': product_id,
            'unit_price': unit_price,
            'sale_price': sale_price,
            'store_id': store_id
        }
        
        prices_dict_list.append(item_dict)
        

    print(f'Parsed {len(item_dict_list)} items.')
    return prices_dict_list


stores_ids = ['5757', '5761', '5760']
prices_info_list = fetch_prices_for_stores(df_categories, stores_ids, 5)
prices_dict_list = parse_prices_data(prices_info_list)
df_prices = pd.DataFrame( prices_dict_list )
df_prices.to_csv('precios.csv', index=False)
# Out:
# Fetching prices for store 5757...
# Fetching prices for store 5761...
# Fetching prices for store 5760...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 0 en 5757
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Deli con skip 0 en 5757
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 0 en 5757
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 0 en 5757
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 0 en 5757
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 100 en 5757
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 100 en 5757
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 100 en 5757
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 100 en 5757
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Deli con skip 100 en 5757
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 200 en 5757
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 83 productos de la categoría Bakery con skip 200 en 5757
# 🛑 Ya no hay más productos para la categoría Bakery en 5757
# Completed 1/63
# ✅ Obtenidos 46 productos de la categoría Deli con skip 200 en 5757
# 🛑 Ya no hay más productos para la categoría Deli en 5757
# Completed 2/63
# ✅ Obtenidos 100 productos de la categoría Home & Floral con skip 0 en 5757
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 0 en 5757
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 200 en 5757
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 200 en 5757
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 300 en 5757
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 99 productos de la categoría Home & Floral con skip 100 en 5757
# 🛑 Ya no hay más productos para la categoría Home & Floral en 5757
# Completed 3/63
# ✅ Obtenidos 100 productos de la categoría Produce con skip 0 en 5757
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 100 en 5757
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 300 en 5757
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 400 en 5757
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 300 en 5757
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 400 en 5757
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Produce con skip 100 en 5757
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 200 en 5757
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 90 productos de la categoría Beer, Wine & Spirits con skip 400 en 5757
# 🛑 Ya no hay más productos para la categoría Beer, Wine & Spirits en 5757
# Completed 4/63
# ✅ Obtenidos 75 productos de la categoría Seafood con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Seafood en 5757
# Completed 5/63
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 500 en 5757
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Produce con skip 200 en 5757
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 61 productos de la categoría Catering con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Catering en 5757
# Completed 6/63
# ✅ Obtenidos 4 productos de la categoría Weekly BOGO con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Weekly BOGO en 5757
# Completed 7/63
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 500 en 5757
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 14 productos de la categoría Meals on a Budget con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Meals on a Budget en 5757
# Completed 8/63
# ✅ Obtenidos 89 productos de la categoría Organic con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Organic en 5757
# Completed 9/63
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 0 en 5757
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 300 en 5757
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 600 en 5757
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 600 en 5757
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 100 en 5757
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 47 productos de la categoría Meat con skip 400 en 5757
# 🛑 Ya no hay más productos para la categoría Meat en 5757
# Completed 10/63
# ✅ Obtenidos 78 productos de la categoría Charcuterie Board Items con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Charcuterie Board Items en 5757
# Completed 11/63
# ✅ Obtenidos 12 productos de la categoría Produce con skip 300 en 5757
# 🛑 Ya no hay más productos para la categoría Produce en 5757
# Completed 12/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 0 en 5757
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 7 productos de la categoría Nestle Deal con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Nestle Deal en 5757
# Completed 13/63
# ✅ Obtenidos 38 productos de la categoría Build Your Own Smoothie con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Build Your Own Smoothie en 5757
# Completed 14/63
# ✅ Obtenidos 64 productos de la categoría Quick Meals con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Quick Meals en 5757
# Completed 15/63
# ✅ Obtenidos 5 productos de la categoría Pan con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Pan en 5757
# Completed 16/63
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 700 en 5757
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 50 productos de la categoría Fair Essentials con skip 0 en 5757
# 🛑 Ya no hay más productos para la categoría Fair Essentials en 5757
# Completed 17/63
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 0 en 5761
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 200 en 5757
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 700 en 5757
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 47 productos de la categoría Sedano's Brand con skip 300 en 5757
# 🛑 Ya no hay más productos para la categoría Sedano's Brand en 5757
# Completed 18/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 100 en 5757
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 0 en 5761
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 100 en 5761
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 77 productos de la categoría Frozen Foods con skip 800 en 5757
# 🛑 Ya no hay más productos para la categoría Frozen Foods en 5757
# Completed 19/63
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 0 en 5761
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 24 productos de la categoría Dairy con skip 800 en 5757
# 🛑 Ya no hay más productos para la categoría Dairy en 5757
# Completed 20/63
# ✅ Obtenidos 100 productos de la categoría Deli con skip 0 en 5761
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 200 en 5757
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 100 en 5761
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 100 en 5761
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 72 productos de la categoría Bakery con skip 200 en 5761
# 🛑 Ya no hay más productos para la categoría Bakery en 5761
# Completed 21/63
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 0 en 5761
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Deli con skip 100 en 5761
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 300 en 5757
# ⏳ Esperando 28s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 200 en 5761
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 57 productos de la categoría Deli con skip 200 en 5761
# 🛑 Ya no hay más productos para la categoría Deli en 5761
# Completed 22/63
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 200 en 5761
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Home & Floral con skip 0 en 5761
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 100 en 5761
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 84 productos de la categoría Beer, Wine & Spirits con skip 300 en 5761
# 🛑 Ya no hay más productos para la categoría Beer, Wine & Spirits en 5761
# Completed 23/63
# ✅ Obtenidos 100 productos de la categoría Meat con skip 0 en 5761
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 300 en 5761
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 400 en 5757
# ⏳ Esperando 16s antes del próximo request...
# ✅ Obtenidos 6 productos de la categoría Home & Floral con skip 100 en 5761
# 🛑 Ya no hay más productos para la categoría Home & Floral en 5761
# Completed 24/63
# ✅ Obtenidos 100 productos de la categoría Produce con skip 0 en 5761
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 200 en 5761
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 100 en 5761
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 500 en 5757
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 400 en 5761
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 300 en 5761
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 200 en 5761
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Produce con skip 100 en 5761
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 78 productos de la categoría Compare and Save con skip 600 en 5757
# 🛑 Ya no hay más productos para la categoría Compare and Save en 5757
# Completed 25/63
# ✅ Obtenidos 77 productos de la categoría Seafood con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Seafood en 5761
# Completed 26/63
# ✅ Obtenidos 61 productos de la categoría Catering con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Catering en 5761
# Completed 27/63
# ✅ Obtenidos 4 productos de la categoría Weekly BOGO con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Weekly BOGO en 5761
# Completed 28/63
# ✅ Obtenidos 14 productos de la categoría Meals on a Budget con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Meals on a Budget en 5761
# Completed 29/63
# ✅ Obtenidos 88 productos de la categoría Organic con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Organic en 5761
# Completed 30/63
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 0 en 5761
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 300 en 5761
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 400 en 5761
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 97 productos de la categoría Produce con skip 200 en 5761
# 🛑 Ya no hay más productos para la categoría Produce en 5761
# Completed 31/63
# ✅ Obtenidos 62 productos de la categoría Charcuterie Board Items con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Charcuterie Board Items en 5761
# Completed 32/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 0 en 5761
# ⏳ Esperando 29s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 500 en 5761
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 100 en 5761
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 40 productos de la categoría Meat con skip 400 en 5761
# 🛑 Ya no hay más productos para la categoría Meat en 5761
# Completed 33/63
# ✅ Obtenidos 7 productos de la categoría Nestle Deal con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Nestle Deal en 5761
# Completed 34/63
# ✅ Obtenidos 29 productos de la categoría Build Your Own Smoothie con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Build Your Own Smoothie en 5761
# Completed 35/63
# ✅ Obtenidos 64 productos de la categoría Quick Meals con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Quick Meals en 5761
# Completed 36/63
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 600 en 5761
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 4 productos de la categoría Pan con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Pan en 5761
# Completed 37/63
# ✅ Obtenidos 48 productos de la categoría Fair Essentials con skip 0 en 5761
# 🛑 Ya no hay más productos para la categoría Fair Essentials en 5761
# Completed 38/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 100 en 5761
# ⏳ Esperando 20s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 500 en 5761
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 0 en 5760
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 65 productos de la categoría Dairy con skip 700 en 5761
# 🛑 Ya no hay más productos para la categoría Dairy en 5761
# Completed 39/63
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 0 en 5760
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 200 en 5761
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 600 en 5761
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 200 en 5761
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Bakery con skip 100 en 5760
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 53 productos de la categoría Bakery con skip 200 en 5760
# 🛑 Ya no hay más productos para la categoría Bakery en 5760
# Completed 40/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 300 en 5761
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 100 en 5760
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 0 en 5760
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 56 productos de la categoría Frozen Foods con skip 700 en 5761
# 🛑 Ya no hay más productos para la categoría Frozen Foods en 5761
# Completed 41/63
# ✅ Obtenidos 100 productos de la categoría Deli con skip 0 en 5760
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 30 productos de la categoría Sedano's Brand con skip 300 en 5761
# 🛑 Ya no hay más productos para la categoría Sedano's Brand en 5761
# Completed 42/63
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 0 en 5760
# ⏳ Esperando 15s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 100 en 5760
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Beer, Wine & Spirits con skip 200 en 5760
# ⏳ Esperando 32s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 100 en 5760
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 400 en 5761
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Deli con skip 100 en 5760
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 200 en 5760
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 42 productos de la categoría Deli con skip 200 en 5760
# 🛑 Ya no hay más productos para la categoría Deli en 5760
# Completed 43/63
# ✅ Obtenidos 100 productos de la categoría Home & Floral con skip 0 en 5760
# ⏳ Esperando 23s antes del próximo request...
# ✅ Obtenidos 73 productos de la categoría Beer, Wine & Spirits con skip 300 en 5760
# 🛑 Ya no hay más productos para la categoría Beer, Wine & Spirits en 5760
# Completed 44/63
# ✅ Obtenidos 100 productos de la categoría Meat con skip 0 en 5760
# ⏳ Esperando 18s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 200 en 5760
# ⏳ Esperando 17s antes del próximo request...
# ✅ Obtenidos 88 productos de la categoría Compare and Save con skip 500 en 5761
# 🛑 Ya no hay más productos para la categoría Compare and Save en 5761
# Completed 45/63
# ✅ Obtenidos 100 productos de la categoría Produce con skip 0 en 5760
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 300 en 5760
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 59 productos de la categoría Home & Floral con skip 100 en 5760
# 🛑 Ya no hay más productos para la categoría Home & Floral en 5760
# Completed 46/63
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 300 en 5760
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 100 en 5760
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 69 productos de la categoría Seafood con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Seafood en 5760
# Completed 47/63
# ✅ Obtenidos 60 productos de la categoría Catering con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Catering en 5760
# Completed 48/63
# ✅ Obtenidos 4 productos de la categoría Weekly BOGO con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Weekly BOGO en 5760
# Completed 49/63
# ✅ Obtenidos 13 productos de la categoría Meals on a Budget con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Meals on a Budget en 5760
# Completed 50/63
# ✅ Obtenidos 82 productos de la categoría Organic con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Organic en 5760
# Completed 51/63
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 0 en 5760
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Produce con skip 100 en 5760
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 400 en 5760
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 200 en 5760
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 400 en 5760
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 100 en 5760
# ⏳ Esperando 22s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 500 en 5760
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 75 productos de la categoría Produce con skip 200 en 5760
# 🛑 Ya no hay más productos para la categoría Produce en 5760
# Completed 52/63
# ✅ Obtenidos 75 productos de la categoría Charcuterie Board Items con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Charcuterie Board Items en 5760
# Completed 53/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 0 en 5760
# ⏳ Esperando 24s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 500 en 5760
# ⏳ Esperando 27s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Meat con skip 300 en 5760
# ⏳ Esperando 30s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Sedano's Brand con skip 200 en 5760
# ⏳ Esperando 26s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 100 en 5760
# ⏳ Esperando 25s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 600 en 5760
# ⏳ Esperando 33s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 600 en 5760
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 16 productos de la categoría Sedano's Brand con skip 300 en 5760
# 🛑 Ya no hay más productos para la categoría Sedano's Brand en 5760
# Completed 54/63
# ✅ Obtenidos 7 productos de la categoría Nestle Deal con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Nestle Deal en 5760
# Completed 55/63
# ✅ Obtenidos 34 productos de la categoría Build Your Own Smoothie con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Build Your Own Smoothie en 5760
# Completed 56/63
# ✅ Obtenidos 55 productos de la categoría Meat con skip 400 en 5760
# 🛑 Ya no hay más productos para la categoría Meat en 5760
# Completed 57/63
# ✅ Obtenidos 64 productos de la categoría Quick Meals con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Quick Meals en 5760
# Completed 58/63
# ✅ Obtenidos 5 productos de la categoría Pan con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Pan en 5760
# Completed 59/63
# ✅ Obtenidos 50 productos de la categoría Fair Essentials con skip 0 en 5760
# 🛑 Ya no hay más productos para la categoría Fair Essentials en 5760
# Completed 60/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 200 en 5760
# ⏳ Esperando 34s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Dairy con skip 700 en 5760
# ⏳ Esperando 35s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Frozen Foods con skip 700 en 5760
# ⏳ Esperando 19s antes del próximo request...
# ✅ Obtenidos 93 productos de la categoría Frozen Foods con skip 800 en 5760
# 🛑 Ya no hay más productos para la categoría Frozen Foods en 5760
# Completed 61/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 300 en 5760
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 3 productos de la categoría Dairy con skip 800 en 5760
# 🛑 Ya no hay más productos para la categoría Dairy en 5760
# Completed 62/63
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 400 en 5760
# ⏳ Esperando 31s antes del próximo request...
# ✅ Obtenidos 100 productos de la categoría Compare and Save con skip 500 en 5760
# ⏳ Esperando 21s antes del próximo request...
# ✅ Obtenidos 51 productos de la categoría Compare and Save con skip 600 en 5760
# 🛑 Ya no hay más productos para la categoría Compare and Save en 5760
# Completed 63/63
# Finished fetching prices for all stores.
# Starting prices-parsing...
# Parsed 4653 items.

# %%
import requests

headers = {
    'Accept': 'application/json',
    'Accept-Language': 'es,es-ES;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    'DNT': '1',
    'Origin': 'https://www.costco.com',
    'Referer': 'https://www.costco.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'x-api-key': '273db6be-f015-4de7-b0d6-dd4746ccd5c3',
}

category_path = 'appliances.html'
start = 0
rows = 100

url = (
    'https://search.costco.com/api/apps/www_costco_com/query/www_costco_com_navigation'
    f'?expoption=def&q=*%3A*&locale=en-US&start={start}&rows={rows}&expand=false&userLocation=WA'
    f'&loc=115-bd%2C1-wh%2C1250-3pl%2C1321-wm%2C1456-3pl%2C283-wm%2C561-wm%2C725-wm%2C731-wm%2C758-wm%2C759-wm%2C847_0-cor'
    '%2C847_0-cwt%2C847_0-edi%2C847_0-ehs%2C847_0-membership%2C847_0-mpt%2C847_0-spc%2C847_0-wm%2C847_1-cwt%2C847_1-edi'
    '%2C847_d-fis%2C847_lg_n1f-edi%2C847_NA-cor%2C847_NA-pharmacy%2C847_NA-wm%2C847_ss_u362-edi%2C847_wp_r458-edi%2C951-wm'
    '%2C952-wm%2C9847-wcs&whloc=1-wh'
    f'&url=/{category_path}'
    '&fq=%7B!tag%3Ditem_program_eligibility%7Ditem_program_eligibility%3A(%22ShipIt%22)'
    '&chdcategory=true&chdheader=true'
)

response = requests.get(url, headers=headers)

data = response.json()
products = data.get('response', {}).get('docs', [])
